# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv("Zomato[1].csv",encoding='latin-1')

# %%
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karakí_y
# 9547                                   Koôuyolu
# 9548                                 Kuruí_eôme
# 9549                                 Kuruí_eôme
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karakí_y, ÛÁstanbul   28.977392
# 9547                               Koôuyolu, ÛÁstanbul   29.041297
# 9548                             Kuruí_eôme, ÛÁstanbul   29.034640
# 9549                             Kuruí_eôme, ÛÁstanbul   29.036019
# 9550                                    Moda, ÛÁstanbul   29.026016
#
#        Latitude                          Cuisines  ...          Currency  \
# 0     14.565443        French, Japanese, Desserts  ...  Botswana Pula(P)
# 1     14.553708                          Japanese  ...  Botswana Pula(P)
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)
# 3     14.585318                   Japanese, Sushi  ...  Botswana Pula(P)
# 4     14.584450                  Japanese, Korean  ...  Botswana Pula(P)
# ...         ...                               ...  ...               ...
# 9546  41.022793                           Turkish  ...  Turkish Lira(TL)
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548  41.055817            Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549  41.057979                   Restaurant Cafe  ...  Turkish Lira(TL)
# 9550  40.984776                              Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 0                  Yes                  No                No
# 1                  Yes                  No                No
# 2                  Yes                  No                No
# 3                   No                  No                No
# 4                  Yes                  No                No
# ...                ...                 ...               ...
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                      No           3               4.8    Dark Green
# 1                      No           3               4.5    Dark Green
# 2                      No           4               4.4         Green
# 3                      No           4               4.9    Dark Green
# 4                      No           4               4.8    Dark Green
# ...                   ...         ...               ...           ...
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 0      Excellent   314
# 1      Excellent   591
# 2      Very Good   270
# 3      Excellent   365
# 4      Excellent   229
# ...          ...   ...
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [9551 rows x 21 columns]

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df1.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# 9547    Koôuyolu, ÛÁstanbul  29.041297  41.009847
# 9548  Kuruí_eôme, ÛÁstanbul  29.034640  41.055817
# 9549  Kuruí_eôme, ÛÁstanbul  29.036019  41.057979
# 9550         Moda, ÛÁstanbul  29.026016  40.984776
#
#                              Cuisines  ...          Currency  \
# 9546                          Turkish  ...  Turkish Lira(TL)
# 9547  World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548           Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549                  Restaurant Cafe  ...  Turkish Lira(TL)
# 9550                             Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [5 rows x 21 columns]

# %%
df1.sample()
# Out:
#       Restaurant ID        Restaurant Name  Country Code       City  \
# 4860           7856  Aggarwal Sweet Corner             1  New Delhi
#
#                                                 Address        Locality  \
# 4860  J-35 B, Central Market, Lajpat Nagar 2, New Delhi  Lajpat Nagar 2
#
#                Locality Verbose  Longitude   Latitude  \
# 4860  Lajpat Nagar 2, New Delhi  77.243703  28.569009
#
#                                         Cuisines  ...            Currency  \
# 4860  North Indian, Chinese, Street Food, Mithai  ...  Indian Rupees(Rs.)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 4860                No                 Yes                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 4860                   No           1               3.4        Orange
#
#      Rating text Votes
# 4860     Average    22
#
# [1 rows x 21 columns]

# %%
df_country = pd.read_excel("Country-Code.xlsx")
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
data=pd.merge(df1,df_country,on='Country Code',how='left')

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karakí_y
# 9547                                   Koôuyolu
# 9548                                 Kuruí_eôme
# 9549                                 Kuruí_eôme
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karakí_y, ÛÁstanbul   28.977392
# 9547                               Koôuyolu, ÛÁstanbul   29.041297
# 9548                             Kuruí_eôme, ÛÁstanbul   29.034640
# 9549                             Kuruí_eôme, ÛÁstanbul   29.036019
# 9550                                    Moda, ÛÁstanbul   29.026016
#
#        Latitude                          Cuisines  ...  Has Table booking  \
# 0     14.565443        French, Japanese, Desserts  ...                Yes
# 1     14.553708                          Japanese  ...                Yes
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...                Yes
# 3     14.585318                   Japanese, Sushi  ...                 No
# 4     14.584450                  Japanese, Korean  ...                Yes
# ...         ...                               ...  ...                ...
# 9546  41.022793                           Turkish  ...                 No
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...                 No
# 9548  41.055817            Italian, World Cuisine  ...                 No
# 9549  41.057979                   Restaurant Cafe  ...                 No
# 9550  40.984776                              Cafe  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                     No                No                   No           3
# 1                     No                No                   No           3
# 2                     No                No                   No           4
# 3                     No                No                   No           4
# 4                     No                No                   No           4
# ...                  ...               ...                  ...         ...
# 9546                  No                No                   No           3
# 9547                  No                No                   No           3
# 9548                  No                No                   No           4
# 9549                  No                No                   No           4
# 9550                  No                No                   No           2
#
#      Aggregate rating  Rating color  Rating text Votes      Country
# 0                 4.8    Dark Green    Excellent   314  Phillipines
# 1                 4.5    Dark Green    Excellent   591  Phillipines
# 2                 4.4         Green    Very Good   270  Phillipines
# 3                 4.9    Dark Green    Excellent   365  Phillipines
# 4                 4.8    Dark Green    Excellent   229  Phillipines
# ...               ...           ...          ...   ...          ...
# 9546              4.1         Green    Very Good   788       Turkey
# 9547              4.2         Green    Very Good  1034       Turkey
# 9548              3.7        Yellow         Good   661       Turkey
# 9549              4.0         Green    Very Good   901       Turkey
# 9550              4.0         Green    Very Good   591       Turkey
#
# [9551 rows x 22 columns]

# %%
data.shape
# Out:
# (9551, 22)

# %%
data.drop_duplicates()
data.shape
# Out:
# (9551, 22)

# %%
data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %%
df1.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %%
data. isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
sns.countplot(x='Country Code',data=data)
plt.show()

# %%
sns.countplot(x='Price range',data=data)
plt.show()

# %%
sns.countplot(y='Currency',data=data)
plt.show()

# %%
sns.countplot(x='Has Table booking',data=data)
plt.show()

# %%
sns.countplot(x='Has Online delivery',data=data)
plt.show()

# %%
a=data[data['Has Online delivery']=='Yes'].Country.value_counts()

# %%
a
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
a.plot.pie(autopct = '%1.1f%%')
plt.title('Country has online delivery')
plt.show()

# %%
sns.countplot(x='Is delivering now',data=data)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Aggregate rating',data=data)
plt.show()

# %%
sns.countplot(x='Rating color',data=data,)
plt.show()

# %%
sns.countplot(x='Rating text',data=data,)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='Country',data=data)
plt.show()

# %%
city_values = data.City.value_counts().values
city_labels = data.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
plt.show()

# %%
cuisin_val=data.Cuisines.value_counts().values
cuisin_label = data.Cuisines.value_counts().index

# %%
plt.pie(cuisin_val[:10],labels=cuisin_label[:10],autopct='%1.2f%%')
plt.show()

# %%
val=data.Locality.value_counts().values
label = data.Locality.value_counts().index

# %%
plt.pie(val[:10],labels=label[:10],autopct='%1.2f%%')
plt.show()

# %%
sns.distplot(data['Average Cost for two'])
plt.show()

# %%
plt.figure(figsize=(15,6))
df_good = data.sort_values(by="Average Cost for two",ascending=False)
sns.barplot(x="Country",y="Average Cost for two",data=df_good)
plt.show()

# %%
plt.figure(figsize=(20,6))
df_good = data.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(x="Restaurant Name",y="Average Cost for two",data=df_good)
plt.show()

# %%
df_good = data.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(y="City",x="Average Cost for two",data=df_good)
plt.show()

# %%
sns.boxplot(x='Has Online delivery',y='Votes',data=data)
plt.title('Has Online delivery VS Votes')
plt.show()

# %%
data.groupby('Restaurant Name')['Aggregate rating'].mean().nlargest(10).plot.bar()
plt.show()

# %%
sns.boxplot(x='Has Online delivery',y='Average Cost for two',data=data)
plt.title('Has Online delivery VS Average Cost for two')
plt.show()

# %%
data.groupby('Restaurant Name')['Votes'].mean().nlargest(10).plot.bar()
plt.show()

# %%
sns.scatterplot(x='Average Cost for two',y='Longitude',data=data)
plt.show()

# %%
sns.scatterplot(x='Average Cost for two',y='Latitude',data=data)
plt.show()

# %%
rating=data.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',data=rating)
plt.show()

# %%
plt.figure(figsize=(10,6))
df_good = data.sort_values(by="Latitude",ascending=False).iloc[0:10,:]
sns.barplot(y="Restaurant Name",x="Latitude",data=df_good)
plt.show()

# %%
sns.barplot(x='Price range',y='Average Cost for two',data=data)
plt.show()

# %%
sns.barplot(x='Rating text',y='Average Cost for two',data=data)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating text',data=rating)
plt.show()

# %%
data[data['Rating color']=='White'].groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %%
Delhi = data[(data.City == 'New Delhi')]
top_locality = Delhi.Locality.value_counts().head(10)
plt.figure(figsize=(12,6))
sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])
plt.title('Resturants Online Delivery')
plt.show()

# %%
sns.countplot(x='Has Online delivery',hue='Has Table booking',data=data)
plt.show()

# %%
sns.countplot(x='Rating color',hue='Price range',data=data)
plt.show()

# %%
sns.scatterplot(x='Votes',y='Average Cost for two',data=data)
plt.show()

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=data)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='Aggregate rating',y='Average Cost for two',hue='Has Online delivery',data=data)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',data=rating, palette=['blue','red','orange','yellow','green','darkgreen'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x="Country", y="Average Cost for two", hue="Has Online delivery",data=data)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Average Cost for two", y="Aggregate rating", hue='Price range', data=Delhi)

plt.xlabel("Average Cost for two")
plt.ylabel("Aggregate rating")
plt.title('Rating vs Cost of Two')
plt.show()

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=data,hue='Has Online delivery')
plt.show()

# %%
data.drop(columns=['Restaurant ID','Locality Verbose'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in data[data.columns[data.dtypes == 'object']]:
    data[col] = le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3749           162    73     8685       171  121.027535
# 1             3173           162    73     6055       593  121.014101
# 2             2897           162    75     4684       308  121.056831
# 3             4707           162    75     8690       862  121.056475
# 4             5523           162    75     8689       862  121.057508
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
# 1  14.553708      1111                  1200         0                  1
# 2  14.581404      1671                  4000         0                  1
# 3  14.585318      1126                  1500         0                  0
# 4  14.584450      1122                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# 0                    0                  0                     0            3
# 1                    0                  0                     0            3
# 2                    0                  0                     0            4
# 3                    0                  0                     0            4
# 4                    0                  0                     0            4
#
#    Aggregate rating  Rating color  Rating text  Votes  Country
# 0               4.8             0            1    314        6
# 1               4.5             0            1    591        6
# 2               4.4             1            5    270        6
# 3               4.9             0            1    365        6
# 4               4.8             0            1    229        6

# %%
data.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9551.000000   9551.000000  9551.000000  9551.000000  9551.000000
# mean       3653.204586     18.365616    78.301434  4542.439430   658.128468
# std        2142.917876     56.750546    23.198915  2565.717005   315.866515
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1777.500000      1.000000    76.000000  2323.500000   381.000000
# 50%        3595.000000      1.000000    88.000000  4610.000000   696.000000
# 75%        5485.500000      1.000000    88.000000  6746.500000   921.000000
# max        7445.000000    216.000000   140.000000  8917.000000  1207.000000
#
#          Longitude     Latitude    Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.00000           9551.000000
# mean     64.126574    25.854381   989.95079           1199.210763
# std      41.467058    11.007935   514.72354          16121.183073
# min    -157.948486   -41.330428     0.00000              0.000000
# 25%      77.081343    28.478713   497.00000            250.000000
# 50%      77.191964    28.570469  1127.00000            400.000000
# 75%      77.282006    28.642758  1355.00000            700.000000
# max     174.832089    55.976980  1825.00000         800000.000000
#
#           Currency  Has Table booking  Has Online delivery  Is delivering now  \
# count  9551.000000        9551.000000          9551.000000        9551.000000
# mean      3.977699           0.121244             0.256622           0.003560
# std       0.914242           0.326428             0.436792           0.059561
# min       0.000000           0.000000             0.000000           0.000000
# 25%       4.000000           0.000000             0.000000           0.000000
# 50%       4.000000           0.000000             0.000000           0.000000
# 75%       4.000000           0.000000             1.000000           0.000000
# max      11.000000           1.000000             1.000000           1.000000
#
#        Switch to order menu  Price range  Aggregate rating  Rating color  \
# count                9551.0  9551.000000       9551.000000   9551.000000
# mean                    0.0     1.804837          2.666370      2.952885
# std                     0.0     0.905609          1.516378      1.493048
# min                     0.0     1.000000          0.000000      0.000000
# 25%                     0.0     1.000000          2.500000      2.000000
# 50%                     0.0     2.000000          3.200000      2.000000
# 75%                     0.0     2.000000          3.700000      4.000000
# max                     0.0     4.000000          4.900000      5.000000
#
#        Rating text         Votes      Country
# count  9551.000000   9551.000000  9551.000000
# mean      1.788713    156.909748     3.736781
# std       1.694637    430.169145     2.651963
# min       0.000000      0.000000     0.000000
# 25%       0.000000      5.000000     3.000000
# 50%       2.000000     31.000000     3.000000
# 75%       3.000000    131.000000     3.000000
# max       5.000000  10934.000000    14.000000

# %%
data.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Country                -0.004034
# Is delivering now      -0.001862
# Cuisines                0.005755
# Has Table booking       0.007758
# Restaurant Name         0.019241
# Address                 0.022749
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot=True, fmt ='.2f')
plt.show()

# %%
plt.figure(figsize = (20,8))
data.corr()['Average Cost for two'].sort_values(ascending = False).drop(['Average Cost for two']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Average Cost for two',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %%
data.shape
# Out:
# (9551, 20)

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

for column in data:
    if plotnumber <=20:
        ax = plt.subplot(5,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %%
data.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# # Checking Outliers

# %%
plt.figure(figsize=(25,30))
plotnumber = 1

for column in data:
    if plotnumber <=20:
        plt.subplot(5,4,plotnumber)
        ax = sns.boxplot(data=data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

z_score = zscore(data[['Average Cost for two','Votes']])
abs_z_score = np.abs(z_score) 
filtering_entry = (abs_z_score  < 3).all(axis=1)

df = data[filtering_entry]

# %%
df.shape
# Out:
# (9362, 20)

# %%
data.shape
# Out:
# (9551, 20)

# %% [markdown]
# # Checking Multicollinearity

# %%
x = df.drop(columns=['Average Cost for two'],axis=1)
y = df['Average Cost for two']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features        vif
# 0        Restaurant Name   1.008700
# 1           Country Code  48.278786
# 2                   City   1.081831
# 3                Address   1.106130
# 4               Locality   1.068078
# 5              Longitude   5.031289
# 6               Latitude   3.037873
# 7               Cuisines   1.043922
# 8               Currency   1.294013
# 9      Has Table booking   1.482431
# 10   Has Online delivery   1.168622
# 11     Is delivering now   1.014266
# 12  Switch to order menu        NaN
# 13           Price range   1.949610
# 14      Aggregate rating   1.947962
# 15          Rating color   1.221294
# 16           Rating text   1.426143
# 17                 Votes   1.613811
# 18               Country  66.489679

# %% [markdown]
# # Droping columns whose having multicollinearity

# %%
df.drop(columns=['Country Code','Switch to order menu','Country'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (9362, 17)

# %%
x = df.drop(columns=['Average Cost for two'],axis=1)
y = df['Average Cost for two']

# %%
data.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %%
x_best = x.drop(columns=['Restaurant Name','Is delivering now']).copy()

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x_best,method='yeo-johnson')

# %%
trans = pd.DataFrame(x)

# %%
trans.skew()
# Out:
# 0    -0.198500
# 1    -0.302620
# 2    -0.306525
# 3    -0.795230
# 4    -0.259015
# 5    -0.382346
# 6     0.447069
# 7     2.382516
# 8     1.120081
# 9     0.197391
# 10   -0.615772
# 11   -0.100142
# 12   -0.055331
# 13   -0.021285
# dtype: float64

# %%
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-0.40644576,  1.47370479, -1.56895768, ..., -2.26885617,
#         -0.20420612,  1.30223393],
#        [-0.40644576,  0.61835876, -0.20264175, ..., -2.26885617,
#         -0.20420612,  1.65627302],
#        [-0.310708  ,  0.13463254, -1.11660629, ..., -1.38742706,
#          1.51689551,  1.21890769],
#        ...,
#        [ 3.88657629,  0.58789144, -0.32621295, ...,  1.32393817,
#          0.39794913,  1.71976831],
#        [ 3.88657629,  0.58823442, -0.32621295, ..., -1.38742706,
#          1.51689551,  1.8967675 ],
#        [ 3.88657629, -0.0228778 ,  0.04024675, ..., -1.38742706,
#          1.51689551,  1.65627302]])

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# # Linear Regression

# %%
LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state {i}, The training accuracy is: {r2_score(y_train,LR_predict_train)}')
    print(f'At random state {i}, The test accuracy is: {r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state 0, The training accuracy is: 0.5349196703571919
# At random state 0, The test accuracy is: 0.537705566503976
#
#
# At random state 1, The training accuracy is: 0.5436474179963355
# At random state 1, The test accuracy is: 0.5058695962669343
#
#
# At random state 2, The training accuracy is: 0.5350410658161804
# At random state 2, The test accuracy is: 0.5358119289710084
#
#
# At random state 3, The training accuracy is: 0.5398726194827328
# At random state 3, The test accuracy is: 0.5158554778875744
#
#
# At random state 4, The training accuracy is: 0.5304249043205624
# At random state 4, The test accuracy is: 0.5587629835671841
#
#
# At random state 5, The training accuracy is: 0.5392918593980505
# At random state 5, The test accuracy is: 0.517333652419498
#
#
# At random state 6, The training accuracy is: 0.5421178743996368
# At random state 6, The test accuracy is: 0.5048381816988476
#
#
# At random state 7, The training accuracy is: 0.5323224007924368
# At random state 7, The test accuracy is: 0.5435832131207443
#
#
# At random state 8, The training accuracy is: 0.5355767011902366
# At random state 8, The test accuracy is: 0.5349717433708057
#
#
# At random state 9, The training accuracy is: 0.5278242764547172
# At random state 9, The test accuracy is: 0.5651512973278132
#
#
# At random state 10, The training accuracy is: 0.5256492495273664
# At random state 10, The test accuracy is: 0.5773911254792272
#
#
# At random state 11, The training accuracy is: 0.5347933275134436
# At random state 11, The test accuracy is: 0.5369365751479295
#
#
# At random state 12, The training accuracy is: 0.5343820054829469
# At random state 12, The test accuracy is: 0.5396908807738262
#
#
# At random state 13, The training accuracy is: 0.5290464208416688
# At random state 13, The test accuracy is: 0.55960755431648
#
#
# At random state 14, The training accuracy is: 0.5313031598090843
# At random state 14, The test accuracy is: 0.5493195476545454
#
#
# At random state 15, The training accuracy is: 0.5411224440364324
# At random state 15, The test accuracy is: 0.5109843041726184
#
#
# At random state 16, The training accuracy is: 0.5303318993194728
# At random state 16, The test accuracy is: 0.558241372104012
#
#
# At random state 17, The training accuracy is: 0.5323224634370076
# At random state 17, The test accuracy is: 0.5493642250714991
#
#
# At random state 18, The training accuracy is: 0.5357060320049221
# At random state 18, The test accuracy is: 0.5328044249136907
#
#
# At random state 19, The training accuracy is: 0.5326439509768428
# At random state 19, The test accuracy is: 0.5466119962289333
#
#
# At random state 20, The training accuracy is: 0.5341238509280162
# At random state 20, The test accuracy is: 0.5407599951578842
#
#
# At random state 21, The training accuracy is: 0.5387011095857162
# At random state 21, The test accuracy is: 0.5190429977723644
#
#
# At random state 22, The training accuracy is: 0.5371861909234217
# At random state 22, The test accuracy is: 0.5264405175396489
#
#
# At random state 23, The training accuracy is: 0.5358482859505523
# At random state 23, The test accuracy is: 0.5337092190540168
#
#
# At random state 24, The training accuracy is: 0.527198288773655
# At random state 24, The test accuracy is: 0.5747144539203017
#
#
# At random state 25, The training accuracy is: 0.5436471067570723
# At random state 25, The test accuracy is: 0.5041664372207448
#
#
# At random state 26, The training accuracy is: 0.539304400327363
# At random state 26, The test accuracy is: 0.515581000165722
#
#
# At random state 27, The training accuracy is: 0.5310615345879799
# At random state 27, The test accuracy is: 0.5548689004346097
#
#
# At random state 28, The training accuracy is: 0.5353092557629351
# At random state 28, The test accuracy is: 0.5339340492382834
#
#
# At random state 29, The training accuracy is: 0.545865460092125
# At random state 29, The test accuracy is: 0.500978487891395
#
#
# At random state 30, The training accuracy is: 0.5324351150087636
# At random state 30, The test accuracy is: 0.5451314590324869
#
#
# At random state 31, The training accuracy is: 0.5338317774302606
# At random state 31, The test accuracy is: 0.5413942725673104
#
#
# At random state 32, The training accuracy is: 0.5324912500467448
# At random state 32, The test accuracy is: 0.5471357738027313
#
#
# At random state 33, The training accuracy is: 0.5348447434186462
# At random state 33, The test accuracy is: 0.5360909254020108
#
#
# At random state 34, The training accuracy is: 0.5294184285935051
# At random state 34, The test accuracy is: 0.5611696924221263
#
#
# At random state 35, The training accuracy is: 0.5334434013874606
# At random state 35, The test accuracy is: 0.542278437684921
#
#
# At random state 36, The training accuracy is: 0.5339277894569243
# At random state 36, The test accuracy is: 0.5400931695885136
#
#
# At random state 37, The training accuracy is: 0.5319265022305029
# At random state 37, The test accuracy is: 0.5502501785679108
#
#
# At random state 38, The training accuracy is: 0.5293804723118557
# At random state 38, The test accuracy is: 0.5568676311381388
#
#
# At random state 39, The training accuracy is: 0.5300905624921382
# At random state 39, The test accuracy is: 0.5602522051132057
#
#
# At random state 40, The training accuracy is: 0.5400175037786368
# At random state 40, The test accuracy is: 0.5191911036786467
#
#
# At random state 41, The training accuracy is: 0.5447989364399353
# At random state 41, The test accuracy is: 0.5016040066081016
#
#
# At random state 42, The training accuracy is: 0.5311973946640491
# At random state 42, The test accuracy is: 0.5532020301108709
#
#
# At random state 43, The training accuracy is: 0.5370247919091398
# At random state 43, The test accuracy is: 0.5275015925773481
#
#
# At random state 44, The training accuracy is: 0.5310350152346008
# At random state 44, The test accuracy is: 0.5567738502385897
#
#
# At random state 45, The training accuracy is: 0.5381284197167884
# At random state 45, The test accuracy is: 0.5231989821883742
#
#
# At random state 46, The training accuracy is: 0.53144806686973
# At random state 46, The test accuracy is: 0.5501918959092618
#
#
# At random state 47, The training accuracy is: 0.53201524868255
# At random state 47, The test accuracy is: 0.5507027740237542
#
#
# At random state 48, The training accuracy is: 0.5504716796267337
# At random state 48, The test accuracy is: 0.4785674009602371
#
#
# At random state 49, The training accuracy is: 0.5332231432544319
# At random state 49, The test accuracy is: 0.5441368883087693
#
#
# At random state 50, The training accuracy is: 0.5431053143984064
# At random state 50, The test accuracy is: 0.5062885995346109
#
#
# At random state 51, The training accuracy is: 0.5303152912210563
# At random state 51, The test accuracy is: 0.5580926804109138
#
#
# At random state 52, The training accuracy is: 0.5395795218740385
# At random state 52, The test accuracy is: 0.5136076551444213
#
#
# At random state 53, The training accuracy is: 0.5286892985883909
# At random state 53, The test accuracy is: 0.5664559895798069
#
#
# At random state 54, The training accuracy is: 0.5258384498386333
# At random state 54, The test accuracy is: 0.5787638255731411
#
#
# At random state 55, The training accuracy is: 0.5305887840637658
# At random state 55, The test accuracy is: 0.5577577003064811
#
#
# At random state 56, The training accuracy is: 0.5488129288231876
# At random state 56, The test accuracy is: 0.4899868968445604
#
#
# At random state 57, The training accuracy is: 0.5321376796855233
# At random state 57, The test accuracy is: 0.5487783845347278
#
#
# At random state 58, The training accuracy is: 0.5398558097904935
# At random state 58, The test accuracy is: 0.5167654155364909
#
#
# At random state 59, The training accuracy is: 0.5403349521218217
# At random state 59, The test accuracy is: 0.515781694664577
#
#
# At random state 60, The training accuracy is: 0.5420345909938027
# At random state 60, The test accuracy is: 0.5104932300560592
#
#
# At random state 61, The training accuracy is: 0.5386450494565177
# At random state 61, The test accuracy is: 0.5232861252438745
#
#
# At random state 62, The training accuracy is: 0.5353407101522729
# At random state 62, The test accuracy is: 0.5352451957071412
#
#
# At random state 63, The training accuracy is: 0.5295309102988499
# At random state 63, The test accuracy is: 0.5621110749322513
#
#
# At random state 64, The training accuracy is: 0.5359920653942252
# At random state 64, The test accuracy is: 0.5310071712328219
#
#
# At random state 65, The training accuracy is: 0.5403884882219828
# At random state 65, The test accuracy is: 0.5147292322036974
#
#
# At random state 66, The training accuracy is: 0.5374239573910319
# At random state 66, The test accuracy is: 0.5248498952530172
#
#
# At random state 67, The training accuracy is: 0.5367578804361305
# At random state 67, The test accuracy is: 0.5294130165171345
#
#
# At random state 68, The training accuracy is: 0.538723802920833
# At random state 68, The test accuracy is: 0.522270165787273
#
#
# At random state 69, The training accuracy is: 0.537217229843318
# At random state 69, The test accuracy is: 0.5287327216415525
#
#
# At random state 70, The training accuracy is: 0.5407551588019777
# At random state 70, The test accuracy is: 0.5134025729248559
#
#
# At random state 71, The training accuracy is: 0.5421433494193646
# At random state 71, The test accuracy is: 0.509860766568489
#
#
# At random state 72, The training accuracy is: 0.5389340213113023
# At random state 72, The test accuracy is: 0.5201424111979212
#
#
# At random state 73, The training accuracy is: 0.5276956583265249
# At random state 73, The test accuracy is: 0.5702311885074894
#
#
# At random state 74, The training accuracy is: 0.540770119994967
# At random state 74, The test accuracy is: 0.5136043533708792
#
#
# At random state 75, The training accuracy is: 0.5353457499716369
# At random state 75, The test accuracy is: 0.5343656963495023
#
#
# At random state 76, The training accuracy is: 0.5466282239218614
# At random state 76, The test accuracy is: 0.49288062636995467
#
#
# At random state 77, The training accuracy is: 0.5367027880382436
# At random state 77, The test accuracy is: 0.5297263985669596
#
#
# At random state 78, The training accuracy is: 0.5434977341410783
# At random state 78, The test accuracy is: 0.5029388133839752
#
#
# At random state 79, The training accuracy is: 0.5411473806540629
# At random state 79, The test accuracy is: 0.5089847794838733
#
#
# At random state 80, The training accuracy is: 0.5376666143234097
# At random state 80, The test accuracy is: 0.5257108324629116
#
#
# At random state 81, The training accuracy is: 0.5401769561916976
# At random state 81, The test accuracy is: 0.5162524901131242
#
#
# At random state 82, The training accuracy is: 0.5272406018901434
# At random state 82, The test accuracy is: 0.5725668023035622
#
#
# At random state 83, The training accuracy is: 0.5435794496347388
# At random state 83, The test accuracy is: 0.5045606461598584
#
#
# At random state 84, The training accuracy is: 0.5400724283571248
# At random state 84, The test accuracy is: 0.510628240663965
#
#
# At random state 85, The training accuracy is: 0.5354187589577686
# At random state 85, The test accuracy is: 0.5354119717581216
#
#
# At random state 86, The training accuracy is: 0.5308039722325864
# At random state 86, The test accuracy is: 0.5523571608024666
#
#
# At random state 87, The training accuracy is: 0.5318221989162845
# At random state 87, The test accuracy is: 0.5482725334813939
#
#
# At random state 88, The training accuracy is: 0.5428134731567211
# At random state 88, The test accuracy is: 0.5048020774544417
#
#
# At random state 89, The training accuracy is: 0.5261689104278817
# At random state 89, The test accuracy is: 0.5697482312262558
#
#
# At random state 90, The training accuracy is: 0.5319236221208365
# At random state 90, The test accuracy is: 0.5480621769140233
#
#
# At random state 91, The training accuracy is: 0.5317475098835318
# At random state 91, The test accuracy is: 0.5483382387640386
#
#
# At random state 92, The training accuracy is: 0.5331246452656953
# At random state 92, The test accuracy is: 0.5434020833197832
#
#
# At random state 93, The training accuracy is: 0.5427022996932354
# At random state 93, The test accuracy is: 0.505246404789484
#
#
# At random state 94, The training accuracy is: 0.5330566382444129
# At random state 94, The test accuracy is: 0.5434399809568787
#
#
# At random state 95, The training accuracy is: 0.5409892010434353
# At random state 95, The test accuracy is: 0.5104082865724053
#
#
# At random state 96, The training accuracy is: 0.5388012536170292
# At random state 96, The test accuracy is: 0.5217777330848024
#
#
# At random state 97, The training accuracy is: 0.5413963561343276
# At random state 97, The test accuracy is: 0.51245842523609
#
#
# At random state 98, The training accuracy is: 0.5448747664463519
# At random state 98, The test accuracy is: 0.501893745208553
#
#
# At random state 99, The training accuracy is: 0.5323290230427655
# At random state 99, The test accuracy is: 0.5493822820593713

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.27,random_state=95)

# %%
x_train.shape
# Out:
# (6834, 14)

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# 0.5425263771149413
# MSE: 172048.27103600386
# MAE: 215.84434720038323
# r2_score: 0.09017825194564444

# %%
svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)
print('MSE:',mean_squared_error(svr_predict,y_test))
print('MAE:',mean_absolute_error(svr_predict,y_test))
print('r2_score:',r2_score(svr_predict,y_test))
# Out:
# 0.482267857434728
# MSE: 190177.77407630888
# MAE: 193.4420476698258
# r2_score: -0.7538395521599146

# %%
svr_p=SVR(kernel='poly')
svr_p.fit(x_train,y_train)
print(svr_p.score(x_train,y_train))
svrpred_p=svr_p.predict(x_test)
print('MSE:',mean_squared_error(svrpred_p,y_test))
print('MAE:',mean_absolute_error(svrpred_p,y_test))
print('r2_score:',r2_score(svrpred_p,y_test))
# Out:
# 0.3111565413951882
# MSE: 244673.1849338696
# MAE: 231.29413742667347
# r2_score: -5.7909445787191345

# %%
svr_r=SVR(kernel='rbf')
svr_r.fit(x_train,y_train)
print(svr_r.score(x_train,y_train))
svrpred_r=svr_r.predict(x_test)
print('MSE:',mean_squared_error(svrpred_r,y_test))
print('MAE:',mean_absolute_error(svrpred_r,y_test))
print('r2_score:',r2_score(svrpred_r,y_test))
# Out:
# 0.2439454593971132
# MSE: 273044.14775214903
# MAE: 245.66828614807326
# r2_score: -13.478761677924245

# %%
RF=RandomForestRegressor()
RF.fit(x_train,y_train)
print(RF.score(x_train,y_train))
RF_PRED=RF.predict(x_test)
print('MSE:',mean_squared_error(RF_PRED,y_test))
print('MAE:',mean_absolute_error(RF_PRED,y_test))
print('r2_score:',r2_score(RF_PRED,y_test))
# Out:
# 0.9843063427320526
# MSE: 58490.47440434247
# MAE: 109.28198444092828
# r2_score: 0.7999440451921792

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)
print('MSE:',mean_squared_error(DTR_PRED,y_test))
print('MAE:',mean_absolute_error(DTR_PRED,y_test))
print('r2_score:',r2_score(DTR_PRED,y_test))
# Out:
# 0.9999868073831297
# MSE: 87758.72982594937
# MAE: 135.5439082278481
# r2_score: 0.7303946852474978

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_PRED=GBR.predict(x_test)
print('MSE:',mean_squared_error(GBR_PRED,y_test))
print('MAE:',mean_absolute_error(GBR_PRED,y_test))
print('r2_score:',r2_score(GBR_PRED,y_test))
# Out:
# 0.9043555459904994
# MSE: 61860.99428281591
# MAE: 118.34149682833785
# r2_score: 0.7696915464103529

# %% [markdown]
# # Cross Validation

# %%
score=cross_val_score(LR,x_train,y_train,cv=5)
print(score)
print(score.mean())
print("Difference between r2_score and cross validation score is -",(r2_score(y_test,LR_predict)-score.mean())*100)
# Out:
# [0.50875411 0.53886183 0.53172049 0.58425135 0.52576863]
# 0.5378712830457439
# Difference between r2_score and cross validation score is - -2.1465305866073203

# %%
score=cross_val_score(svr,x_train,y_train)
print(score)
print(score.mean())
print("Difference between r2_score and cross validation score is -",(r2_score(y_test,svr_predict)-score.mean())*100)
# Out:
# [0.48141078 0.47554451 0.47458284 0.50986931 0.45724286]
# 0.47973006081596187
# Difference between r2_score and cross validation score is - -1.4282569032286585

# %%
score=cross_val_score(svr_p,x_train,y_train)
print(score)
print(score.mean())
print("Difference between r2_score and cross validation score is -",(r2_score(y_test,svrpred_p)-score.mean())*100)
# Out:
# [0.30050904 0.2422591  0.2789521  0.27397573 0.25252366]
# 0.2696439262529145
# Difference between r2_score and cross validation score is - 4.262762948000259

# %%
score=cross_val_score(svr_r,x_train,y_train)
print(score)
print(score.mean())
print("Difference between r2_score and cross validation score is -",(r2_score(y_test,svrpred_r)-score.mean())*100)
# Out:
# [0.22906169 0.19863976 0.22309274 0.19410771 0.18398028]
# 0.20577643625984948
# Difference between r2_score and cross validation score is - 2.6749894729096777

# %%
score=cross_val_score(RF,x_train,y_train)
print(score)
print(score.mean())
print("Difference between r2_score and cross validation score is -",(r2_score(y_test,RF_PRED)-score.mean())*100)
# Out:
# [0.86500839 0.88686711 0.88031898 0.85054611 0.88999616]
# 0.8745473509150165
# Difference between r2_score and cross validation score is - -3.8952628826505853

# %%
score=cross_val_score(DTR,x_train,y_train)
print(score)
print(score.mean())
print("Difference between r2_score and cross validation score is -",(r2_score(y_test,DTR_PRED)-score.mean())*100)
# Out:
# [0.74139206 0.79629277 0.77229127 0.73124947 0.76170435]
# 0.7605859860644688
# Difference between r2_score and cross validation score is - -0.725860264224365

# %%
score=cross_val_score(GBR,x_train,y_train)
print(score)
print(score.mean())
print("Difference between r2_score and cross validation score is -",(r2_score(y_test,GBR_PRED)-score.mean())*100)
# Out:
# [0.85996673 0.8589853  0.88058118 0.85515205 0.88593898]
# 0.8681248495638554
# Difference between r2_score and cross validation score is - -4.20039992975485

# %% [markdown]
# # HYPER PARAMETER TUNING:

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'criterion':['squared_error', 'absolute_error', 'friedman_mse','poisson'],
              'splitter':['best','random'],
     'min_samples_split':[2,4],
    'min_samples_leaf':[1,2],
 }
DTR=DecisionTreeRegressor()

clf = GridSearchCV(DecisionTreeRegressor(), parameters, cv=5)
clf.fit(x_train, y_train)
clf.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'min_samples_leaf': 2,
#  'min_samples_split': 4,
#  'splitter': 'random'}

# %%
clf_pred=clf.best_estimator_.predict(x_test)

# %%
r2_score(y_test, clf_pred)
# Out:
# 0.749573147252209

# %%
print('MSE:',mean_squared_error(clf_pred,y_test))
print('MAE:',mean_absolute_error(clf_pred,y_test))
print('r2_score:',r2_score(clf_pred,y_test))
# Out:
# MSE: 89094.37462640647
# MAE: 132.8529799578059
# r2_score: 0.7347364339858168

# %%
sns.distplot(clf_pred-y_test)
# Out:
# <Axes: xlabel='Average Cost for two', ylabel='Density'>

# %%
plt.scatter(clf_pred,y_test)
plt.plot(y_test,y_test,linewidth=2,color='Red')

# %%
import joblib
joblib.dump(clf,"Average_cost_for_two_prediction.pkl")
# Out:
# ['Average_cost_for_two_prediction.pkl']
