# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing the dataset:

# %%
df=pd.read_csv("baseball[1].csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# # Identifing type of problem:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.sample()
# Out:
#     W    R    AB     H   2B  3B   HR   BB   SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383  973  104  641  601  3.73   2    8
#
#    SV   E
# 0  56  88

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no null values.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# # Data Visualization:

# %%
sns.heatmap(df.isnull(),cmap="cool_r")
# Out:
# <Axes: >

# %% [markdown]
# NO need to change the datatype they are appropriate.

# %%
plt.figure(figsize=(15,10))
sns.histplot(x='R',data=df,kde=True)
plt.show()

# %%
sns.pairplot(df,kind='reg',height=1.5)

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='AB',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='H',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='2B',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='3B',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='HR',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='BB',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='SO',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='SB',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='RA',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='ER',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='ERA',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='CG',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='SHO',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='SV',data=df,kde=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='E',data=df,kde=True)
plt.show()

# %%
plt.boxplot(df['R'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb1730fd90>,
#   <matplotlib.lines.Line2D at 0x2bb1730e4a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb1730ec50>,
#   <matplotlib.lines.Line2D at 0x2bb1730ea40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb1730f970>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb1730f5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb1730ee90>],
#  'means': []}

# %%
plt.boxplot(df['AB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb17184970>,
#   <matplotlib.lines.Line2D at 0x2bb17184e80>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb16edd810>,
#   <matplotlib.lines.Line2D at 0x2bb16ede320>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb179ff760>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb16eded70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb16ede0b0>],
#  'means': []}

# %%
plt.boxplot(df['H'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb15086cb0>,
#   <matplotlib.lines.Line2D at 0x2bb0fba1720>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb155324a0>,
#   <matplotlib.lines.Line2D at 0x2bb15532410>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb1536fb80>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb15532f20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb15533460>],
#  'means': []}

# %%
plt.boxplot(df['2B'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb15587190>,
#   <matplotlib.lines.Line2D at 0x2bb15585ea0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb15585f60>,
#   <matplotlib.lines.Line2D at 0x2bb15585c60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb15587400>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb15585960>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb15587be0>],
#  'means': []}

# %%
plt.boxplot(df['3B'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb1815be50>,
#   <matplotlib.lines.Line2D at 0x2bb17a256f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb17a25300>,
#   <matplotlib.lines.Line2D at 0x2bb17a27670>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb17a24f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb17a256c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb17a26c20>],
#  'means': []}

# %%
plt.boxplot(df['HR'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb155a84f0>,
#   <matplotlib.lines.Line2D at 0x2bb155a8370>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb155ab7c0>,
#   <matplotlib.lines.Line2D at 0x2bb155ab730>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb155a8ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb155aa050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb155aa590>],
#  'means': []}

# %%
plt.boxplot(df['BB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb16f1ebc0>,
#   <matplotlib.lines.Line2D at 0x2bb16f1ee60>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb16f1f100>,
#   <matplotlib.lines.Line2D at 0x2bb16f1f3a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb16f1e920>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb16f1f640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb16f1f8e0>],
#  'means': []}

# %%
plt.boxplot(df['SO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb16f8f220>,
#   <matplotlib.lines.Line2D at 0x2bb16f8f4c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb16f8f640>,
#   <matplotlib.lines.Line2D at 0x2bb16f8f8e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb16f8ef80>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb16f8fb80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb16f8fe20>],
#  'means': []}

# %%
plt.boxplot(df['SB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb17011cc0>,
#   <matplotlib.lines.Line2D at 0x2bb17011f60>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb17012200>,
#   <matplotlib.lines.Line2D at 0x2bb170124a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb17011a20>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb17012740>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb170129e0>],
#  'means': []}

# %%
plt.boxplot(df['RA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb17073c10>,
#   <matplotlib.lines.Line2D at 0x2bb17073eb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb170a41c0>,
#   <matplotlib.lines.Line2D at 0x2bb170a4460>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb17073a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb170a4700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb170a49a0>],
#  'means': []}

# %%
plt.boxplot(df['ER'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb170ef4c0>,
#   <matplotlib.lines.Line2D at 0x2bb170ef760>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb170efa00>,
#   <matplotlib.lines.Line2D at 0x2bb170efca0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb170ef340>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb170eff40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb1894c220>],
#  'means': []}

# %%
plt.boxplot(df['ERA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb1898e680>,
#   <matplotlib.lines.Line2D at 0x2bb1898e920>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb1898ebc0>,
#   <matplotlib.lines.Line2D at 0x2bb1898ee60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb1898e500>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb1898f100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb1898f3a0>],
#  'means': []}

# %%
plt.boxplot(df['CG'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb18a188e0>,
#   <matplotlib.lines.Line2D at 0x2bb18a18b80>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb18a18e20>,
#   <matplotlib.lines.Line2D at 0x2bb18a190c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb18a18640>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb18a19360>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb18a19600>],
#  'means': []}

# %%
plt.boxplot(df['SHO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb19bf2fe0>,
#   <matplotlib.lines.Line2D at 0x2bb19bf3280>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb19bf3520>,
#   <matplotlib.lines.Line2D at 0x2bb19bf37c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb19bf2d40>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb19bf3a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb19bf3d00>],
#  'means': []}

# %%
plt.boxplot(df['SV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb19c6a7a0>,
#   <matplotlib.lines.Line2D at 0x2bb19c6aa40>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb19c6ace0>,
#   <matplotlib.lines.Line2D at 0x2bb19c6af80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb19c6a500>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb19c6b220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb19c6b4c0>],
#  'means': []}

# %%
plt.boxplot(df['E'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bb19aa9a80>,
#   <matplotlib.lines.Line2D at 0x2bb19aa9d20>],
#  'caps': [<matplotlib.lines.Line2D at 0x2bb19aa9fc0>,
#   <matplotlib.lines.Line2D at 0x2bb19aaa260>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2bb19aa97e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bb19aaa500>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bb19aaa7a0>],
#  'means': []}

# %%
plt.figure(figsize=(10,5))
sns.regplot(x='R',y='W',data=df)
plt.show()

# %%
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df_new.shape
# Out:
# (29, 17)

# %%
Dataloss = (((30-29)/30)*100)

# %%
Dataloss
# Out:
# 3.3333333333333335

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
skew_features=["H","CG","SHO","SV","E"]

# %%
df_new["H"]=np.log1p(df_new["H"])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %%
df_new[['E','SHO','SV','CG']] = scaler.fit_transform(df_new[['E','SHO','SV','CG']].values)

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.732868
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[skew_features]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
x = df_new.drop("W",axis=1)
y = df_new["W"]

# %%
#Importing necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
ssc=StandardScaler()
X = pd.DataFrame(ssc.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.721918  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.951179  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.086505  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.346243 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.026702  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.307098 -0.787002
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.307098  0.236737
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.011315 -0.252844
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.264463 -0.513555
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.264463  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.105886        R
# 1      20.235707       AB
# 2      10.100185        H
# 3       3.527912       2B
# 4       3.228198       3B
# 5       8.736802       HR
# 6       3.322251       BB
# 7       2.811688       SO
# 8       1.954864       SB
# 9     201.021790       RA
# 10   2078.458414       ER
# 11   1614.575945      ERA
# 12      2.909799       CG
# 13      3.272216      SHO
# 14      5.904507       SV
# 15      2.335147        E

# %%
X = X.drop(["ER"],axis=1)

# %%
X.head(10)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.721918  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.951179  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.086505  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.346243 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.026702  0.908319  1.704094 -0.353293 -0.197495
# 5  1.856900  0.716535 -0.049639 -0.093474 -1.266972  1.743939  1.643442
# 6  0.712585 -0.447345 -0.552402 -1.625627 -1.167936  1.915843 -0.885522
# 7 -0.835605 -0.447345 -0.308958  0.260100  0.020490  0.196801 -0.550807
# 8  1.497899  1.752672  1.687800  1.202964  0.119526 -0.009484  0.230197
# 9  1.565212 -0.078310  0.352036  0.319029  0.020490  0.368705  0.695081
#
#          SO        SB        RA       ERA        CG       SHO        SV  \
# 0 -2.727623  0.905953 -0.664514 -0.511388 -0.307098 -0.787002  1.532753
# 1  0.121896 -0.585315  0.154638  0.238952 -0.307098  0.236737  0.312020
# 2 -0.925866  0.116458 -0.678397 -0.643801  2.011315 -0.252844 -0.664137
# 3 -0.201246 -0.673037  0.168522  0.040333  1.264463 -0.513555 -0.820689
# 4  0.072935 -0.015124  1.584683  1.496876  1.264463  0.236737 -1.149165
# 5 -0.240414 -0.892341  0.126870  0.150677  0.121871 -2.064039  0.677176
# 6  0.777970 -1.725697  0.057451  0.194815 -1.732896 -0.252844  0.052325
# 7  0.572335  0.160319 -0.650630 -0.489319 -0.870682  0.236737  1.908137
# 8 -1.013995 -0.541454  0.890486  0.768604  0.121871 -0.252844 -0.365006
# 9 -0.181661  0.774370  0.612808  0.614123  0.770649 -0.513555  0.312020
#
#           E
# 0 -0.348265
# 1 -0.540820
# 2 -1.326125
# 3  0.650818
# 4 -0.540820
# 5  0.082858
# 6 -1.588197
# 7  0.237592
# 8  0.383386
# 9  1.554265

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.058626        R
# 1       7.802499       AB
# 2       9.331726        H
# 3       3.227945       2B
# 4       3.125723       3B
# 5       7.471123       HR
# 6       3.321201       BB
# 7       2.786340       SO
# 8       1.787421       SB
# 9     142.865570       RA
# 10    141.780924      ERA
# 11      2.535436       CG
# 12      3.135247      SHO
# 13      2.626954       SV
# 14      2.266677        E

# %%
X = X.drop(["ERA"],axis=1)

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.008286        R
# 1       5.205086       AB
# 2       7.703193        H
# 3       3.165739       2B
# 4       2.981260       3B
# 5       6.159975       HR
# 6       3.050932       BB
# 7       2.288108       SO
# 8       1.773279       SB
# 9       4.754881       RA
# 10      2.521668       CG
# 11      3.119957      SHO
# 12      2.603001       SV
# 13      2.234406        E

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import  LinearRegression

LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9768379651848901
# At random state0, The test accuracy is :-0.49953034662392115
#
#
# At random state1, The training accuracy is :-0.9762008405337443
# At random state1, The test accuracy is :-0.18551996166091123
#
#
# At random state2, The training accuracy is :-0.9637789181520225
# At random state2, The test accuracy is :--0.2682651439422532
#
#
# At random state3, The training accuracy is :-0.9678024722205714
# At random state3, The test accuracy is :-0.67806410477755
#
#
# At random state4, The training accuracy is :-0.9680369202756722
# At random state4, The test accuracy is :-0.7641785533002787
#
#
# At random state5, The training accuracy is :-0.961244566807135
# At random state5, The test accuracy is :-0.6056973672383092
#
#
# At random state6, The training accuracy is :-0.9723702251664925
# At random state6, The test accuracy is :-0.7503950577954296
#
#
# At random state7, The training accuracy is :-0.9610227110152545
# At random state7, The test accuracy is :-0.31598216003771074
#
#
# At random state8, The training accuracy is :-0.9717862080880451
# At random state8, The test accuracy is :-0.7204890732819437
#
#
# At random state9, The training accuracy is :-0.9788415571944342
# At random state9, The test accuracy is :-0.6103038475986384
#
#
# At random state10, The training accuracy is :-0.9898492839489759
# At random state10, The test accuracy is :--0.31719194506387494
#
#
# At random state11, The training accuracy is :-0.9672915428252664
# At random state11, The test accuracy is :-0.4157103260408922
#
#
# At random state12, The training accuracy is :-0.9820615112192336
# At random state12, The test accuracy is :-0.4448495315210691
#
#
# At random state13, The training accuracy is :-0.9762152355058024
# At random state13, The test accuracy is :-0.0182450248545577
#
#
# At random state14, The training accuracy is :-0.9544775003151647
# At random state14, The test accuracy is :-0.8479200704887175
#
#
# At random state15, The training accuracy is :-0.9866062507862103
# At random state15, The test accuracy is :--0.12130249209443833
#
#
# At random state16, The training accuracy is :-0.992502183368451
# At random state16, The test accuracy is :--0.9939109753662732
#
#
# At random state17, The training accuracy is :-0.955229115458038
# At random state17, The test accuracy is :-0.7892243658420539
#
#
# At random state18, The training accuracy is :-0.9752773480576712
# At random state18, The test accuracy is :-0.36464349906221905
#
#
# At random state19, The training accuracy is :-0.9639405189231662
# At random state19, The test accuracy is :-0.3098473690964786
#
#
# At random state20, The training accuracy is :-0.9768832918930077
# At random state20, The test accuracy is :--0.9866240261762438
#
#
# At random state21, The training accuracy is :-0.9762534022501816
# At random state21, The test accuracy is :--0.08447588055245214
#
#
# At random state22, The training accuracy is :-0.9622699072562044
# At random state22, The test accuracy is :-0.6148945359661125
#
#
# At random state23, The training accuracy is :-0.9842722472628279
# At random state23, The test accuracy is :-0.6347787597012067
#
#
# At random state24, The training accuracy is :-0.9917417189889398
# At random state24, The test accuracy is :--1.8151152139110414
#
#
# At random state25, The training accuracy is :-0.9676367699786854
# At random state25, The test accuracy is :--0.06871030490308083
#
#
# At random state26, The training accuracy is :-0.9676623680179333
# At random state26, The test accuracy is :--0.5257863707117156
#
#
# At random state27, The training accuracy is :-0.9738617455181605
# At random state27, The test accuracy is :-0.7796633684177184
#
#
# At random state28, The training accuracy is :-0.9792807522362007
# At random state28, The test accuracy is :-0.535738351378955
#
#
# At random state29, The training accuracy is :-0.9605460563112407
# At random state29, The test accuracy is :-0.799179501078819
#
#
# At random state30, The training accuracy is :-0.955919063224447
# At random state30, The test accuracy is :-0.8339770658978624
#
#
# At random state31, The training accuracy is :-0.9803678987704052
# At random state31, The test accuracy is :-0.09699058779916792
#
#
# At random state32, The training accuracy is :-0.9727871346262957
# At random state32, The test accuracy is :-0.4739744926208842
#
#
# At random state33, The training accuracy is :-0.9628304886117083
# At random state33, The test accuracy is :-0.6972810408227148
#
#
# At random state34, The training accuracy is :-0.9799830313500764
# At random state34, The test accuracy is :-0.5025824640949635
#
#
# At random state35, The training accuracy is :-0.9747337218602838
# At random state35, The test accuracy is :-0.8131297704189013
#
#
# At random state36, The training accuracy is :-0.9828561803272902
# At random state36, The test accuracy is :--0.14820528040985592
#
#
# At random state37, The training accuracy is :-0.9780908066329213
# At random state37, The test accuracy is :--0.11406989960036862
#
#
# At random state38, The training accuracy is :-0.962954940491634
# At random state38, The test accuracy is :-0.46926688120448656
#
#
# At random state39, The training accuracy is :-0.9819504875035896
# At random state39, The test accuracy is :--0.0037911840353719306
#
#
# At random state40, The training accuracy is :-0.9860632337175742
# At random state40, The test accuracy is :--0.1946009201260741
#
#
# At random state41, The training accuracy is :-0.9545857574042114
# At random state41, The test accuracy is :-0.8088038385709517
#
#
# At random state42, The training accuracy is :-0.9662038142322971
# At random state42, The test accuracy is :-0.5812046840435923
#
#
# At random state43, The training accuracy is :-0.9860078780263191
# At random state43, The test accuracy is :--5.4897586659705855
#
#
# At random state44, The training accuracy is :-0.9845331948919178
# At random state44, The test accuracy is :-0.0720468388958837
#
#
# At random state45, The training accuracy is :-0.9811586004946066
# At random state45, The test accuracy is :-0.19960526424733271
#
#
# At random state46, The training accuracy is :-0.967294795423949
# At random state46, The test accuracy is :--0.27250641445980395
#
#
# At random state47, The training accuracy is :-0.9714880852140666
# At random state47, The test accuracy is :--0.29051647695918614
#
#
# At random state48, The training accuracy is :-0.9890477696671335
# At random state48, The test accuracy is :--0.7192126806350851
#
#
# At random state49, The training accuracy is :-0.9835141026933606
# At random state49, The test accuracy is :--0.16870592886101532
#
#
# At random state50, The training accuracy is :-0.9537473352726017
# At random state50, The test accuracy is :-0.8315097991868579
#
#
# At random state51, The training accuracy is :-0.9707722616504776
# At random state51, The test accuracy is :-0.7377406529870622
#
#
# At random state52, The training accuracy is :-0.9892008632895696
# At random state52, The test accuracy is :--0.13066345862223927
#
#
# At random state53, The training accuracy is :-0.9761937327239962
# At random state53, The test accuracy is :-0.45102736135956034
#
#
# At random state54, The training accuracy is :-0.9761390313785816
# At random state54, The test accuracy is :--0.05341021757882736
#
#
# At random state55, The training accuracy is :-0.9615052765154398
# At random state55, The test accuracy is :-0.3787908535900427
#
#
# At random state56, The training accuracy is :-0.9749378168833954
# At random state56, The test accuracy is :-0.7245341535132885
#
#
# At random state57, The training accuracy is :-0.9653672745086002
# At random state57, The test accuracy is :-0.7587352211969812
#
#
# At random state58, The training accuracy is :-0.9863654796860091
# At random state58, The test accuracy is :-0.6829289342905498
#
#
# At random state59, The training accuracy is :-0.9709606666385453
# At random state59, The test accuracy is :-0.8212904178632638
#
#
# At random state60, The training accuracy is :-0.9895052417030509
# At random state60, The test accuracy is :-0.11752261100321615
#
#
# At random state61, The training accuracy is :-0.9743052932532494
# At random state61, The test accuracy is :-0.715747006831354
#
#
# At random state62, The training accuracy is :-0.9813583681120315
# At random state62, The test accuracy is :-0.793451240981863
#
#
# At random state63, The training accuracy is :-0.9819975358731635
# At random state63, The test accuracy is :-0.5978769141674052
#
#
# At random state64, The training accuracy is :-0.9570149114529053
# At random state64, The test accuracy is :-0.7483516272500292
#
#
# At random state65, The training accuracy is :-0.9785912720415288
# At random state65, The test accuracy is :-0.3891261052241265
#
#
# At random state66, The training accuracy is :-0.9556675655126992
# At random state66, The test accuracy is :-0.6294999743746397
#
#
# At random state67, The training accuracy is :-0.9598873845325311
# At random state67, The test accuracy is :-0.6181531394084816
#
#
# At random state68, The training accuracy is :-0.9608295151811777
# At random state68, The test accuracy is :-0.3344788951431129
#
#
# At random state69, The training accuracy is :-0.9709083942803218
# At random state69, The test accuracy is :-0.35889634868791664
#
#
# At random state70, The training accuracy is :-0.9676907028735976
# At random state70, The test accuracy is :-0.47587303345082643
#
#
# At random state71, The training accuracy is :-0.9908542044266119
# At random state71, The test accuracy is :--1.4432907718539183
#
#
# At random state72, The training accuracy is :-0.9730126123550489
# At random state72, The test accuracy is :--1.931413992634615
#
#
# At random state73, The training accuracy is :-0.9861547380671716
# At random state73, The test accuracy is :-0.2468169937718513
#
#
# At random state74, The training accuracy is :-0.9671904989359033
# At random state74, The test accuracy is :-0.3732904139450681
#
#
# At random state75, The training accuracy is :-0.965198851491933
# At random state75, The test accuracy is :-0.4403754790372987
#
#
# At random state76, The training accuracy is :-0.9697613765312578
# At random state76, The test accuracy is :-0.6483165985046588
#
#
# At random state77, The training accuracy is :-0.9581284624535413
# At random state77, The test accuracy is :-0.8072392516807846
#
#
# At random state78, The training accuracy is :-0.962438719558901
# At random state78, The test accuracy is :-0.18985406159378881
#
#
# At random state79, The training accuracy is :-0.9748115305530315
# At random state79, The test accuracy is :-0.6938952658258906
#
#
# At random state80, The training accuracy is :-0.9697844036708961
# At random state80, The test accuracy is :-0.7185723424698212
#
#
# At random state81, The training accuracy is :-0.9727093351747572
# At random state81, The test accuracy is :-0.8184783873905914
#
#
# At random state82, The training accuracy is :-0.9798359953121284
# At random state82, The test accuracy is :-0.45801279191323196
#
#
# At random state83, The training accuracy is :-0.9756256373610659
# At random state83, The test accuracy is :-0.28371340925984345
#
#
# At random state84, The training accuracy is :-0.9828475819991497
# At random state84, The test accuracy is :-0.23396593378781227
#
#
# At random state85, The training accuracy is :-0.9668594332813407
# At random state85, The test accuracy is :-0.2485490703298704
#
#
# At random state86, The training accuracy is :-0.9676046466707048
# At random state86, The test accuracy is :--1.0583773193843555
#
#
# At random state87, The training accuracy is :-0.9668287596404942
# At random state87, The test accuracy is :-0.11469157732520596
#
#
# At random state88, The training accuracy is :-0.9922832296876296
# At random state88, The test accuracy is :--1.7230638606454503
#
#
# At random state89, The training accuracy is :-0.9701854658951098
# At random state89, The test accuracy is :-0.5929682331033271
#
#
# At random state90, The training accuracy is :-0.9668401646992705
# At random state90, The test accuracy is :-0.5646117405176156
#
#
# At random state91, The training accuracy is :-0.9844029454147243
# At random state91, The test accuracy is :-0.3714248088490346
#
#
# At random state92, The training accuracy is :-0.9876267202963349
# At random state92, The test accuracy is :-0.42575541719813825
#
#
# At random state93, The training accuracy is :-0.9749351144938321
# At random state93, The test accuracy is :--0.41811965034692666
#
#
# At random state94, The training accuracy is :-0.9792108192401898
# At random state94, The test accuracy is :--0.6034655663313433
#
#
# At random state95, The training accuracy is :-0.9718304812505524
# At random state95, The test accuracy is :-0.4131707345807677
#
#
# At random state96, The training accuracy is :-0.9942928324775395
# At random state96, The test accuracy is :--1.3884695361212227
#
#
# At random state97, The training accuracy is :-0.9600617180794115
# At random state97, The test accuracy is :-0.6780001238069742
#
#
# At random state98, The training accuracy is :-0.9930289218301663
# At random state98, The test accuracy is :--2.7712660291856963
#
#
# At random state99, The training accuracy is :-0.9632794429715599
# At random state99, The test accuracy is :-0.8014295528074404

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)

# %%
x_train.shape
# Out:
# (22, 16)

# %%
y_train.shape
# Out:
# (22,)

# %%
x_test.shape
# Out:
# (7, 16)

# %%
y_test.shape
# Out:
# (7,)

# %%
#Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor 
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %%
from sklearn.linear_model import LinearRegression

LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.9632794429715599

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# MSE: 26.94074148849258
# MAE: 4.984938358024887
# r2_score: 0.8705893253409343

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mae:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: -1.4737148052177227e+27
# mae: 1.999440005119882e+29
# mae: 357880289853162.56
# rmse: 447150981785781.4

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred=ls.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8162585359689938
# mse: 24.92884189547204
# mae: 4.824282278813722
# rmse: 4.992879118852372

# %%
parameters={'alpha':[0.001,0.01,0.1,1,10],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
rd=Ridge()
Z1=GridSearchCV(rd,parameters)
Z1.fit(x_train,y_train)
print(Z1.best_params_)
# Out:
# {'alpha': 10, 'solver': 'saga'}

# %%
rd=Ridge(alpha=10,solver='lsqr')
rd.fit(x_train,y_train)
pred=rd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8517966866054834
# mse: 20.107257702994833
# mae: 4.278790576632259
# rmse: 4.484111696088182

# %%
from sklearn.model_selection import cross_val_score

np.random.seed(10)
def rmse_cv(model,x,y):
    rmse =-(cross_val_score(model,x,y, scoring='neg_mean_squared_error', cv=10))
    return(rmse)

models = [LinearRegression(),
         Ridge(),
         SVR(kernel='linear'),
         SVR(kernel='poly'),
         SVR(kernel='rbf'),
         RandomForestRegressor(),
         DecisionTreeRegressor(),
         GradientBoostingRegressor(),]

names = ['LR','R','svr','svr_p','svr_r','RF','DTR','GBR']

for model,name in zip(models,names):
    score = rmse_cv(model,x,y)
    print("{}   : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR   : 33.220567, 22.187378
# R   : 32.539950, 32.613041
# svr   : 55.759367, 43.789456
# svr_p   : 111.892072, 79.769043
# svr_r   : 112.275507, 79.777702
# RF   : 39.864027, 24.023091
# DTR   : 70.216667, 45.490539
# GBR   : 47.569624, 31.099844

# %%
#Importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'alpha':[0.01,0.1,1.0,10.26],
            'selection':['cyclic','random'],
            'max_iter':[2,4,6,8,10],
            'tol':[100,1000]}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
print(GVC.best_params_)
# Out:
# {'alpha': 1.0, 'max_iter': 6, 'selection': 'random', 'tol': 1000}

# %%
Final_mod=Lasso(alpha=1.0, max_iter=4, selection="random", tol=1000)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 70.18652536124294
# mean_squared_error: 40.44897538744018
# mean_absolute_error: 5.21633686844705
# RMSE value: 6.35995089504944

# %%
#Saving the model using .pkl
import joblib
joblib.dump(Final_mod,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']

# %%
#Loading the saved model
model=joblib.load("BaseballCaseStudy.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([68.3455719 , 68.62522154, 83.91308803, 74.51259088, 87.06771695,
#        86.20172151, 91.1032481 ])

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1          2          3          4          5  \
# Predicted  68.345572  68.625222  83.913088  74.512591  87.067717  86.201722
# Original   67.000000  63.000000  97.000000  76.000000  83.000000  92.000000
#
#                    6
# Predicted  91.103248
# Original   86.000000
