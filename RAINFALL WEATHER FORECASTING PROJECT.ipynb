# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("weatherAUS[1].csv")

# %%
df
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0              W           44.0          W  ...        71.0         22.0
# 1            WNW           44.0        NNW  ...        44.0         25.0
# 2            WSW           46.0          W  ...        38.0         30.0
# 3             NE           24.0         SE  ...        45.0         16.0
# 4              W           41.0        ENE  ...        82.0         33.0
# ...          ...            ...        ...  ...         ...          ...
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0          1007.7       1007.1       8.0       NaN     16.9     21.8
# 1          1010.6       1007.8       NaN       NaN     17.2     24.3
# 2          1007.6       1008.7       NaN       2.0     21.0     23.2
# 3          1017.6       1012.8       NaN       NaN     18.1     26.5
# 4          1010.8       1006.0       7.0       8.0     17.8     29.7
# ...           ...          ...       ...       ...      ...      ...
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 0            No            No
# 1            No            No
# 2            No            No
# 3            No            No
# 4            No            No
# ...         ...           ...
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [8425 rows x 23 columns]

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 8420  2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 8421  2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 8422  2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 8423  2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 8424  2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 8420           E           31.0         SE  ...        51.0         24.0
# 8421         NNW           22.0         SE  ...        56.0         21.0
# 8422           N           37.0         SE  ...        53.0         24.0
# 8423          SE           28.0        SSE  ...        51.0         24.0
# 8424         NaN            NaN        ESE  ...        62.0         36.0
#
#       Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 8420       1024.6       1020.3       NaN       NaN     10.1     22.4
# 8421       1023.5       1019.1       NaN       NaN     10.9     24.5
# 8422       1021.0       1016.8       NaN       NaN     12.5     26.1
# 8423       1019.4       1016.5       3.0       2.0     15.1     26.0
# 8424       1020.2       1017.9       8.0       8.0     15.0     20.9
#
#       RainToday  RainTomorrow
# 8420         No            No
# 8421         No            No
# 8422         No            No
# 8423         No            No
# 8424         No           NaN
#
# [5 rows x 23 columns]

# %%
df.sample()
# Out:
#             Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 4884  2010-10-04  Melbourne     15.5     23.5       0.0          6.8
#
#       Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 4884       6.5         NNE           61.0          N  ...        54.0
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 4884         47.0       1021.8       1018.2       7.0       5.0     18.6
#
#       Temp3pm  RainToday  RainTomorrow
# 4884     22.7         No           Yes
#
# [1 rows x 23 columns]

# %%
df.shape
# Out:
# (8425, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8425 entries, 0 to 8424
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8425 non-null   object
#  1   Location       8425 non-null   object
#  2   MinTemp        8350 non-null   float64
#  3   MaxTemp        8365 non-null   float64
#  4   Rainfall       8185 non-null   float64
#  5   Evaporation    4913 non-null   float64
#  6   Sunshine       4431 non-null   float64
#  7   WindGustDir    7434 non-null   object
#  8   WindGustSpeed  7434 non-null   float64
#  9   WindDir9am     7596 non-null   object
#  10  WindDir3pm     8117 non-null   object
#  11  WindSpeed9am   8349 non-null   float64
#  12  WindSpeed3pm   8318 non-null   float64
#  13  Humidity9am    8366 non-null   float64
#  14  Humidity3pm    8323 non-null   float64
#  15  Pressure9am    7116 non-null   float64
#  16  Pressure3pm    7113 non-null   float64
#  17  Cloud9am       6004 non-null   float64
#  18  Cloud3pm       5970 non-null   float64
#  19  Temp9am        8369 non-null   float64
#  20  Temp3pm        8329 non-null   float64
#  21  RainToday      8185 non-null   object
#  22  RainTomorrow   8186 non-null   object
# dtypes: float64(16), object(7)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Date                0
# Location            0
# MinTemp            75
# MaxTemp            60
# Rainfall          240
# Evaporation      3512
# Sunshine         3994
# WindGustDir       991
# WindGustSpeed     991
# WindDir9am        829
# WindDir3pm        308
# WindSpeed9am       76
# WindSpeed3pm      107
# Humidity9am        59
# Humidity3pm       102
# Pressure9am      1309
# Pressure3pm      1312
# Cloud9am         2421
# Cloud3pm         2455
# Temp9am            56
# Temp3pm            96
# RainToday         240
# RainTomorrow      239
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
elements = df.select_dtypes(include=['object']).columns

print(elements)

for i in elements:
    df[i] = df[i].fillna(df[i].mode()[0])
# Out:
# Index(['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm',
#        'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
cont = df.select_dtypes(include=['float']).columns

print(cont)

for i in cont:
    df[i] = df[i].fillna(df[i].mean())
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am',
#        'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm',
#        'Temp9am', 'Temp3pm'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
catg_features=[col for col in df.columns if df[col].dtypes=='object']
cont_features=[col for col in df.columns if df[col].dtypes!='object']

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean     13.193305    23.859976     2.805913     5.389395     7.632205
# std       5.379488     6.114516    10.309308     3.852004     2.825451
# min      -2.000000     8.200000     0.000000     0.000000     0.000000
# 25%       9.300000    19.300000     0.000000     4.000000     7.632205
# 50%      13.200000    23.300000     0.000000     5.389395     7.632205
# 75%      17.300000    28.000000     1.400000     5.389395     8.900000
# max      28.500000    45.500000   371.000000   145.000000    13.900000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    8425.000000   8425.000000   8425.000000  8425.000000  8425.000000
# mean       40.174469     13.847646     18.533662    67.822496    51.249790
# std        13.776101     10.128579      9.704759    16.774231    18.311894
# min         7.000000      0.000000      0.000000    10.000000     6.000000
# 25%        31.000000      6.000000     11.000000    56.000000    39.000000
# 50%        40.174469     13.000000     19.000000    68.000000    51.000000
# 75%        48.000000     20.000000     24.000000    80.000000    63.000000
# max       107.000000     63.000000     83.000000   100.000000    99.000000
#
#        Pressure9am  Pressure3pm     Cloud9am     Cloud3pm      Temp9am  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean   1017.640233  1015.236075     4.566622     4.503183    17.762015
# std       6.275759     6.217451     2.429205     2.299419     5.608301
# min     989.800000   982.900000     0.000000     0.000000     1.900000
# 25%    1014.000000  1011.400000     3.000000     3.000000    13.800000
# 50%    1017.640233  1015.236075     4.566622     4.503183    17.762015
# 75%    1021.300000  1018.800000     7.000000     7.000000    21.900000
# max    1039.000000  1036.000000     8.000000     8.000000    39.400000
#
#            Temp3pm
# count  8425.000000
# mean     22.442934
# std       5.945849
# min       7.300000
# 25%      18.100000
# 50%      22.000000
# 75%      26.300000
# max      44.100000

# %%
catg_features
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
cont_features
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
df['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['RainTomorrow'].value_counts()
# Out:
# No     6434
# Yes    1991
# Name: RainTomorrow, dtype: int64

# %%
target_df=df['RainTomorrow'].value_counts()

# %%
plt.figure(figsize=(8,6))
plt.title("Target Fetaure ( Rain Tomorrow)",fontsize=15)
ax=sns.barplot(x=target_df.index,y=target_df.values)
plt.xlabel('Rain Tomorrow')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
df['Date'].nunique()
# Out:
# 3004

# %%
df['Location'].unique()
# Out:
# array(['Albury', 'CoffsHarbour', 'Newcastle', 'Penrith', 'Williamtown',
#        'Wollongong', 'Melbourne', 'Brisbane', 'Adelaide', 'PerthAirport',
#        'Darwin', 'Uluru'], dtype=object)

# %%
df['Location'].value_counts()
# Out:
# Melbourne       1622
# Williamtown     1230
# PerthAirport    1204
# Albury           907
# Newcastle        822
# CoffsHarbour     611
# Brisbane         579
# Penrith          482
# Wollongong       474
# Darwin           250
# Adelaide         205
# Uluru             39
# Name: Location, dtype: int64

# %%
sns.countplot(data=df, x='Location')
# Out:
# <Axes: xlabel='Location', ylabel='count'>

# %%
sns.distplot(df['MinTemp'])
# Out:
# <Axes: xlabel='MinTemp', ylabel='Density'>

# %%
sns.distplot(df['MaxTemp'])
# Out:
# <Axes: xlabel='MaxTemp', ylabel='Density'>

# %%
df['Day']= df['Date'].str.split('-').str[2]
df['Month']= df['Date'].str.split('-').str[1]
df['Year'] = df['Date'].str.split('-').str[0]

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6     5.389395  7.632205
# 1  2008-12-02   Albury      7.4     25.1       0.0     5.389395  7.632205
# 2  2008-12-03   Albury     12.9     25.7       0.0     5.389395  7.632205
# 3  2008-12-04   Albury      9.2     28.0       0.0     5.389395  7.632205
# 4  2008-12-05   Albury     17.5     32.3       1.0     5.389395  7.632205
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Pressure3pm  Cloud9am  Cloud3pm  \
# 0           W           44.0          W  ...      1007.1  8.000000  4.503183
# 1         WNW           44.0        NNW  ...      1007.8  4.566622  4.503183
# 2         WSW           46.0          W  ...      1008.7  4.566622  2.000000
# 3          NE           24.0         SE  ...      1012.8  4.566622  4.503183
# 4           W           41.0        ENE  ...      1006.0  7.000000  8.000000
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  Day  Month  Year
# 0     16.9     21.8         No            No   01     12  2008
# 1     17.2     24.3         No            No   02     12  2008
# 2     21.0     23.2         No            No   03     12  2008
# 3     18.1     26.5         No            No   04     12  2008
# 4     17.8     29.7         No            No   05     12  2008
#
# [5 rows x 26 columns]

# %%
df['Month'].unique()
# Out:
# array(['12', '01', '02', '03', '04', '05', '06', '07', '08', '09', '10',
#        '11'], dtype=object)

# %%
df['Year'].unique()
# Out:
# array(['2008', '2009', '2010', '2011', '2013', '2014', '2015', '2016',
#        '2017', '2012'], dtype=object)

# %%
df['Day'] = df['Day'].astype(int)
df['Month'] = df['Month'].astype(int)
df['Year'] = df['Year'].astype(int)

# %%
df['Location'].unique()
# Out:
# array(['Albury', 'CoffsHarbour', 'Newcastle', 'Penrith', 'Williamtown',
#        'Wollongong', 'Melbourne', 'Brisbane', 'Adelaide', 'PerthAirport',
#        'Darwin', 'Uluru'], dtype=object)

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='WindGustDir',data=df)
print(df['WindGustDir'].value_counts())
# Out:
# N      1704
# SSE     578
# S       577
# SW      572
# E       557
# WNW     531
# W       507
# WSW     504
# SE      484
# ENE     415
# SSW     396
# NW      383
# NE      353
# NNE     343
# ESE     302
# NNW     219
# Name: WindGustDir, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='WindDir9am',data=df)
print(df['WindDir9am'].value_counts())
# Out:
# N      1735
# SW      704
# NW      625
# WSW     543
# SE      505
# WNW     480
# SSW     467
# ENE     433
# NNE     430
# W       414
# NE      409
# S       402
# E       380
# SSE     365
# NNW     280
# ESE     253
# Name: WindDir9am, dtype: int64

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='WindDir3pm',data=df)
print(df['WindDir3pm'].value_counts())
# Out:
# SE     1121
# S       742
# SSE     623
# WSW     580
# NE      544
# N       524
# SW      494
# WNW     487
# NW      468
# W       462
# ESE     462
# E       460
# ENE     417
# SSW     370
# NNE     365
# NNW     306
# Name: WindDir3pm, dtype: int64

# %%
plt.figure(figsize=(10,6))
palette_color = sns.color_palette('bright')
plt.pie(df['RainToday'].value_counts()*100.0 /len(df),
        labels=['NO', 'Yes'],
        colors=palette_color,
        autopct='%.2f%%')
plt.title('% Rain Today')
plt.show()

# %%
plt.figure(figsize=(10,6))
palette_color = sns.color_palette('bright')
plt.pie(df['RainTomorrow'].value_counts()*100.0 /len(df),
        labels=['NO', 'Yes'],
        colors=palette_color,
        autopct='%.2f%%')
plt.title('% Rain Today')
plt.show()

# %%
sns.distplot(df['Rainfall'])
# Out:
# <Axes: xlabel='Rainfall', ylabel='Density'>

# %%
sns.distplot(df['Evaporation'])
# Out:
# <Axes: xlabel='Evaporation', ylabel='Density'>

# %%
sns.distplot(df['Sunshine'])
# Out:
# <Axes: xlabel='Sunshine', ylabel='Density'>

# %%
sns.distplot(df['WindGustSpeed'])
# Out:
# <Axes: xlabel='WindGustSpeed', ylabel='Density'>

# %%
sns.distplot(df['WindSpeed9am'])
# Out:
# <Axes: xlabel='WindSpeed9am', ylabel='Density'>

# %%
sns.distplot(df['WindSpeed3pm'])
# Out:
# <Axes: xlabel='WindSpeed3pm', ylabel='Density'>

# %%
sns.distplot(df['Humidity9am'])
# Out:
# <Axes: xlabel='Humidity9am', ylabel='Density'>

# %%
sns.distplot(df['Humidity3pm'])
# Out:
# <Axes: xlabel='Humidity3pm', ylabel='Density'>

# %%
sns.distplot(df['Pressure9am'])
# Out:
# <Axes: xlabel='Pressure9am', ylabel='Density'>

# %%
sns.distplot(df['Pressure3pm'])
# Out:
# <Axes: xlabel='Pressure3pm', ylabel='Density'>

# %%
sns.distplot(df['Cloud9am'])
# Out:
# <Axes: xlabel='Cloud9am', ylabel='Density'>

# %%
sns.distplot(df['Cloud3pm'])
# Out:
# <Axes: xlabel='Cloud3pm', ylabel='Density'>

# %%
sns.distplot(df['Temp9am'])
# Out:
# <Axes: xlabel='Temp9am', ylabel='Density'>

# %%
sns.distplot(df['Temp3pm'])
# Out:
# <Axes: xlabel='Temp3pm', ylabel='Density'>

# %%
df['Avg_WindSpeed']=(df['WindSpeed9am']+df['WindSpeed3pm'])/2

df['Avg_Humidity']=(df['Humidity9am']+df['Humidity3pm'])/2

df['Avg_Cloud']=(df['Cloud9am']+df['Cloud3pm'])/2

df['Avg_Temp'] = (df['Temp9am']+df['Temp3pm'])/2

df['Avg_Pressure']=(df['Pressure9am']+df['Pressure3pm'])/2

# %%
df = df.drop(columns = ['Date', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'Pressure9am', 'Pressure3pm'], axis=1)

df.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6     5.389395  7.632205           W
# 1   Albury      7.4     25.1       0.0     5.389395  7.632205         WNW
# 2   Albury     12.9     25.7       0.0     5.389395  7.632205         WSW
# 3   Albury      9.2     28.0       0.0     5.389395  7.632205          NE
# 4   Albury     17.5     32.3       1.0     5.389395  7.632205           W
#
#    WindGustSpeed WindDir9am WindDir3pm RainToday RainTomorrow  Day  Month  \
# 0           44.0          W        WNW        No           No    1     12
# 1           44.0        NNW        WSW        No           No    2     12
# 2           46.0          W        WSW        No           No    3     12
# 3           24.0         SE          E        No           No    4     12
# 4           41.0        ENE         NW        No           No    5     12
#
#    Year  Avg_WindSpeed  Avg_Humidity  Avg_Cloud  Avg_Temp  Avg_Pressure
# 0  2008           22.0          46.5   6.251591     19.35       1007.40
# 1  2008           13.0          34.5   4.534902     20.75       1009.20
# 2  2008           22.5          34.0   3.283311     22.10       1008.15
# 3  2008           10.0          30.5   4.534902     22.30       1015.20
# 4  2008           13.5          57.5   7.500000     23.75       1008.40

# %%
sns.distplot(df['Avg_WindSpeed'])
# Out:
# <Axes: xlabel='Avg_WindSpeed', ylabel='Density'>

# %%
sns.distplot(df['Avg_Cloud'])
# Out:
# <Axes: xlabel='Avg_Cloud', ylabel='Density'>

# %%
sns.distplot(df['Avg_Humidity'])
# Out:
# <Axes: xlabel='Avg_Humidity', ylabel='Density'>

# %%
sns.distplot(df['Avg_Pressure'])
# Out:
# <Axes: xlabel='Avg_Pressure', ylabel='Density'>

# %%
sns.distplot(df['Avg_Temp'])
# Out:
# <Axes: xlabel='Avg_Temp', ylabel='Density'>

# %%
sns.barplot(y='Avg_Temp', x='RainToday', data = df)
# Out:
# <Axes: xlabel='RainToday', ylabel='Avg_Temp'>

# %%
sns.barplot(y='Avg_Pressure', x='RainToday', data = df)
# Out:
# <Axes: xlabel='RainToday', ylabel='Avg_Pressure'>

# %%
sns.barplot(y='Avg_Cloud', x='RainToday', data = df)
# Out:
# <Axes: xlabel='RainToday', ylabel='Avg_Cloud'>

# %%
sns.barplot(y='Avg_Humidity', x='RainToday', data = df)
# Out:
# <Axes: xlabel='RainToday', ylabel='Avg_Humidity'>

# %%
sns.barplot(y='Avg_WindSpeed', x='RainToday', data = df)
# Out:
# <Axes: xlabel='RainToday', ylabel='Avg_WindSpeed'>

# %% [markdown]
# # Data Encoding

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()

catg = df.select_dtypes(include=['object']).columns

catg
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday',
#        'RainTomorrow'],
#       dtype='object')

# %%
for i in catg:
    df[i] = enc.fit_transform(df[i])

# %%
df.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         1     13.4     22.9       0.6     5.389395  7.632205           13
# 1         1      7.4     25.1       0.0     5.389395  7.632205           14
# 2         1     12.9     25.7       0.0     5.389395  7.632205           15
# 3         1      9.2     28.0       0.0     5.389395  7.632205            4
# 4         1     17.5     32.3       1.0     5.389395  7.632205           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  RainToday  RainTomorrow  Day  Month  \
# 0           44.0          13          14          0             0    1     12
# 1           44.0           6          15          0             0    2     12
# 2           46.0          13          15          0             0    3     12
# 3           24.0           9           0          0             0    4     12
# 4           41.0           1           7          0             0    5     12
#
#    Year  Avg_WindSpeed  Avg_Humidity  Avg_Cloud  Avg_Temp  Avg_Pressure
# 0  2008           22.0          46.5   6.251591     19.35       1007.40
# 1  2008           13.0          34.5   4.534902     20.75       1009.20
# 2  2008           22.5          34.0   3.283311     22.10       1008.15
# 3  2008           10.0          30.5   4.534902     22.30       1015.20
# 4  2008           13.5          57.5   7.500000     23.75       1008.40

# %%
df.describe()
# Out:
#           Location      MinTemp      MaxTemp     Rainfall  Evaporation  \
# count  8425.000000  8425.000000  8425.000000  8425.000000  8425.000000
# mean      5.793591    13.193305    23.859976     2.805913     5.389395
# std       3.162654     5.379488     6.114516    10.309308     3.852004
# min       0.000000    -2.000000     8.200000     0.000000     0.000000
# 25%       3.000000     9.300000    19.300000     0.000000     4.000000
# 50%       6.000000    13.200000    23.300000     0.000000     5.389395
# 75%       8.000000    17.300000    28.000000     1.400000     5.389395
# max      11.000000    28.500000    45.500000   371.000000   145.000000
#
#           Sunshine  WindGustDir  WindGustSpeed   WindDir9am   WindDir3pm  \
# count  8425.000000  8425.000000    8425.000000  8425.000000  8425.000000
# mean      7.632205     7.217804      40.174469     7.267418     7.810445
# std       2.825451     4.702616      13.776101     4.588045     4.430162
# min       0.000000     0.000000       7.000000     0.000000     0.000000
# 25%       7.632205     3.000000      31.000000     3.000000     4.000000
# 50%       7.632205     7.000000      40.174469     7.000000     8.000000
# 75%       8.900000    12.000000      48.000000    12.000000    11.000000
# max      13.900000    15.000000     107.000000    15.000000    15.000000
#
#          RainToday  RainTomorrow          Day        Month         Year  \
# count  8425.000000   8425.000000  8425.000000  8425.000000  8425.000000
# mean      0.236202      0.236320    15.741958     6.442136  2012.102433
# std       0.424773      0.424846     8.787354     3.437994     2.473137
# min       0.000000      0.000000     1.000000     1.000000  2008.000000
# 25%       0.000000      0.000000     8.000000     3.000000  2010.000000
# 50%       0.000000      0.000000    16.000000     6.000000  2011.000000
# 75%       0.000000      0.000000    23.000000     9.000000  2014.000000
# max       1.000000      1.000000    31.000000    12.000000  2017.000000
#
#        Avg_WindSpeed  Avg_Humidity    Avg_Cloud     Avg_Temp  Avg_Pressure
# count    8425.000000   8425.000000  8425.000000  8425.000000   8425.000000
# mean       16.190654     59.536143     4.534902    20.102474   1016.438154
# std         8.760580     15.856811     2.098294     5.532595      6.186076
# min         0.000000      8.500000     0.000000     4.900000    986.350000
# 25%         9.500000     49.000000     3.500000    16.050000   1012.700000
# 50%        15.500000     60.000000     4.534902    19.850000   1016.438154
# 75%        21.500000     70.500000     6.251591    24.000000   1020.050000
# max        60.000000     98.500000     8.000000    37.150000   1037.300000

# %%
df_corr = df.corr()

plt.figure(figsize = (20,10))
sns.heatmap(df_corr, annot = True)
plt.show()

# %% [markdown]
# # Checking Skewness and Outliers

# %%
x = df.drop(['RainTomorrow'], axis=1)
y = df['RainTomorrow']

# %%
print(x.shape)
print(y.shape)
# Out:
# (8425, 19)
# (8425,)

# %%
x.skew().sort_values(ascending = False)
# Out:
# Evaporation      14.023948
# Rainfall         13.218403
# RainToday         1.242362
# WindGustSpeed     0.757000
# Avg_WindSpeed     0.644306
# Year              0.418663
# MaxTemp           0.380654
# WindDir9am        0.172792
# Avg_Temp          0.170653
# WindGustDir       0.119640
# Month             0.039388
# Avg_Pressure      0.005032
# Day               0.004260
# Location         -0.050456
# MinTemp          -0.089989
# WindDir3pm       -0.119847
# Avg_Humidity     -0.151055
# Avg_Cloud        -0.374727
# Sunshine         -0.716525
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new = power_transform(x)

# %%
pd.DataFrame(x_new, columns = x.columns).skew().sort_values(ascending = False)
# Out:
# RainToday        1.242362
# Rainfall         0.904387
# Evaporation      0.080305
# WindGustSpeed    0.010481
# Avg_Pressure     0.000947
# Year             0.000000
# MaxTemp         -0.010591
# Avg_WindSpeed   -0.023574
# Avg_Temp        -0.029065
# Avg_Humidity    -0.047725
# Sunshine        -0.075544
# MinTemp         -0.102983
# WindDir9am      -0.155025
# Month           -0.155749
# Location        -0.186657
# WindGustDir     -0.187177
# Avg_Cloud       -0.192919
# Day             -0.211250
# WindDir3pm      -0.248689
# dtype: float64

# %%
x = pd.DataFrame(x_new, columns = x.columns)

# %%
from scipy.stats import zscore

print('High Side Outliers present')
print((zscore(x)<3).all())

print('Low Side Outliers Present')
print((zscore(x)>-3).all())
# Out:
# High Side Outliers present
# Location          True
# MinTemp           True
# MaxTemp           True
# Rainfall          True
# Evaporation      False
# Sunshine          True
# WindGustDir       True
# WindGustSpeed    False
# WindDir9am        True
# WindDir3pm        True
# RainToday         True
# Day               True
# Month             True
# Year              True
# Avg_WindSpeed    False
# Avg_Humidity      True
# Avg_Cloud         True
# Avg_Temp          True
# Avg_Pressure     False
# dtype: bool
# Low Side Outliers Present
# Location          True
# MinTemp           True
# MaxTemp          False
# Rainfall          True
# Evaporation      False
# Sunshine          True
# WindGustDir       True
# WindGustSpeed    False
# WindDir9am        True
# WindDir3pm        True
# RainToday         True
# Day               True
# Month             True
# Year              True
# Avg_WindSpeed     True
# Avg_Humidity      True
# Avg_Cloud         True
# Avg_Temp         False
# Avg_Pressure     False
# dtype: bool

# %%
Data_loss = ((8425-6255)/8425)*100

Data_loss
# Out:
# 25.7566765578635

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x.columns


vif
# Out:
#           vif       features
# 0    1.562349       Location
# 1    7.326045        MinTemp
# 2   18.502903        MaxTemp
# 3    5.111436       Rainfall
# 4    1.460726    Evaporation
# 5    1.996188       Sunshine
# 6    1.575908    WindGustDir
# 7    2.264799  WindGustSpeed
# 8    1.301562     WindDir9am
# 9    1.413713     WindDir3pm
# 10   4.698011      RainToday
# 11   1.002908            Day
# 12   1.145632          Month
# 13   1.505220           Year
# 14   2.223373  Avg_WindSpeed
# 15   2.596985   Avg_Humidity
# 16   2.001649      Avg_Cloud
# 17  30.055223       Avg_Temp
# 18   1.490225   Avg_Pressure

# %%
x = x.drop(['Avg_Temp'], axis=1)

x.head()
# Out:
#    Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0  -1.57287  0.041124 -0.077141  0.534236     0.195503 -0.082709     1.160646
# 1  -1.57287 -1.076281  0.280346 -0.698529     0.195503 -0.082709     1.319872
# 2  -1.57287 -0.051713  0.374368 -0.698529     0.195503 -0.082709     1.474872
# 3  -1.57287 -0.740202  0.722385 -0.698529     0.195503 -0.082709    -0.578373
# 4  -1.57287  0.800894  1.327005  0.888946     0.195503 -0.082709     1.160646
#
#    WindGustSpeed  WindDir9am  WindDir3pm  RainToday       Day     Month  \
# 0       0.380260    1.179858    1.349376  -0.556099 -1.893365  1.511409
# 1       0.380260   -0.140685    1.552244  -0.556099 -1.710758  1.511409
# 2       0.515699    1.179858    1.552244  -0.556099 -1.544131  1.511409
# 3      -1.265782    0.473499   -1.874337  -0.556099 -1.388459  1.511409
# 4       0.169468   -1.528740   -0.137530  -0.556099 -1.240995  1.511409
#
#            Year  Avg_WindSpeed  Avg_Humidity  Avg_Cloud  Avg_Pressure
# 0 -3.785861e-13       0.720439     -0.834088   0.820975     -1.461738
# 1 -3.785861e-13      -0.256648     -1.554871  -0.044404     -1.170337
# 2 -3.785861e-13       0.769440     -1.584206  -0.641697     -1.340310
# 3 -3.785861e-13      -0.639112     -1.787793  -0.044404     -0.199654
# 4 -3.785861e-13      -0.196414     -0.149109   1.478348     -1.299837

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x.columns

 
vif
# Out:
#          vif       features
# 0   1.560298       Location
# 1   3.972776        MinTemp
# 2   4.802325        MaxTemp
# 3   5.100251       Rainfall
# 4   1.460010    Evaporation
# 5   1.992528       Sunshine
# 6   1.575831    WindGustDir
# 7   2.233958  WindGustSpeed
# 8   1.301492     WindDir9am
# 9   1.410977     WindDir3pm
# 10  4.688545      RainToday
# 11  1.002888            Day
# 12  1.141993          Month
# 13  1.494710           Year
# 14  2.218644  Avg_WindSpeed
# 15  2.433493   Avg_Humidity
# 16  1.977950      Avg_Cloud
# 17  1.485755   Avg_Pressure

# %% [markdown]
# # Model Building

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.svm import SVC

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
LR = LogisticRegression()

# %%
def classifier(model, X, Y):
    x_train,x_test,y_train,y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=36)
    
    model.fit(x_train, y_train)

    pred = model.predict(x_test)
    
    acc_score = (accuracy_score(y_test, pred))*100
    print("Accuracy Score:", acc_score)
    
    class_report = classification_report(y_test, pred)
    print("\nClassification Report:\n", class_report)
    
    cv_score = (cross_val_score(model, x_scaled,y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)

# %% [markdown]
# # Logistic Regression

# %%
model = LogisticRegression()
classifier(model, x_scaled, y)
# Out:
# Accuracy Score: 83.50148367952522
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      1286
#            1       0.73      0.48      0.58       399
#
#     accuracy                           0.84      1685
#    macro avg       0.79      0.71      0.74      1685
# weighted avg       0.83      0.84      0.82      1685
#
# Cross Validation Score: 81.81602373887239
#
# Accuracy Score - Cross Validation Score is 1.6854599406528337

# %% [markdown]
# # SVC Classifier

# %%
model = SVC(kernel='rbf')
classifier(model, x_scaled,y)
# Out:
# Accuracy Score: 84.03560830860533
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      1286
#            1       0.76      0.48      0.59       399
#
#     accuracy                           0.84      1685
#    macro avg       0.81      0.71      0.74      1685
# weighted avg       0.83      0.84      0.83      1685
#
# Cross Validation Score: 81.60237388724035
#
# Accuracy Score - Cross Validation Score is 2.433234421364986

# %%
model = SVC(kernel='linear')
classifier(model, x_scaled,y)
# Out:
# Accuracy Score: 82.90801186943621
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      1286
#            1       0.73      0.44      0.55       399
#
#     accuracy                           0.83      1685
#    macro avg       0.79      0.69      0.72      1685
# weighted avg       0.82      0.83      0.81      1685
#
# Cross Validation Score: 81.53115727002968
#
# Accuracy Score - Cross Validation Score is 1.3768545994065278

# %%
model = SVC(kernel='poly')
classifier(model, x_scaled,y)
# Out:
# Accuracy Score: 83.79821958456974
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90      1286
#            1       0.77      0.45      0.57       399
#
#     accuracy                           0.84      1685
#    macro avg       0.81      0.71      0.74      1685
# weighted avg       0.83      0.84      0.82      1685
#
# Cross Validation Score: 80.98516320474778
#
# Accuracy Score - Cross Validation Score is 2.8130563798219583

# %% [markdown]
# # Decision Tree Classifier

# %%
model = DecisionTreeClassifier()
classifier(model, x_scaled,y)
# Out:
# Accuracy Score: 83.44213649851632
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      1286
#            1       0.64      0.68      0.66       399
#
#     accuracy                           0.83      1685
#    macro avg       0.77      0.78      0.77      1685
# weighted avg       0.84      0.83      0.84      1685
#
# Cross Validation Score: 77.38872403560832
#
# Accuracy Score - Cross Validation Score is 6.053412462908

# %% [markdown]
# # KNeighbors Classifier

# %%
model = KNeighborsClassifier()
classifier(model, x_scaled,y)
# Out:
# Accuracy Score: 84.15430267062315
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90      1286
#            1       0.73      0.53      0.61       399
#
#     accuracy                           0.84      1685
#    macro avg       0.80      0.73      0.76      1685
# weighted avg       0.83      0.84      0.83      1685
#
# Cross Validation Score: 78.71810089020771
#
# Accuracy Score - Cross Validation Score is 5.436201780415445

# %% [markdown]
# # Random Forest Classifier

# %%
model = RandomForestClassifier()
classifier(model,x_scaled,y)
# Out:
# Accuracy Score: 89.02077151335311
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93      1286
#            1       0.85      0.65      0.74       399
#
#     accuracy                           0.89      1685
#    macro avg       0.88      0.81      0.83      1685
# weighted avg       0.89      0.89      0.88      1685
#
# Cross Validation Score: 84.14243323442136
#
# Accuracy Score - Cross Validation Score is 4.87833827893175

# %% [markdown]
# # Hyper Parameter Tuning

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=.20,random_state=36)

# %%
x_test.shape
# Out:
# (1685, 18)

# %%
y_test.shape
# Out:
# (1685,)

# %%
x_train.shape
# Out:
# (6740, 18)

# %%
y_train.shape
# Out:
# (6740,)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"max_depth": np.arange(1,100, 10),
              "n_estimators": np.arange(1,200, 10)}

rf = RandomForestClassifier()

grd = GridSearchCV(rf, param_grid = param_grid)
grd.fit(x_train, y_train)

print('Best Param ==>', grd.best_params_)

rf = grd.best_estimator_

rf.fit(x_train, y_train)
yr_pred = rf.predict(x_test)


print('R2 Score: ', rf.score(x_test, y_test))
# Out:
# Best Param ==> {'max_depth': 41, 'n_estimators': 161}
# R2 Score:  0.886646884272997

# %%
from sklearn.metrics import RocCurveDisplay
from sklearn import datasets
from sklearn import metrics

# %%
fpr,tpr,thresholds=metrics.roc_curve(y_test,yr_pred)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,estimator_name=grd)
display.plot()

# %%
import joblib
joblib.dump(grd, "Rainfall_Prediction_Classifier.pkl")
# Out:
# ['Rainfall_Prediction_Classifier.pkl']
