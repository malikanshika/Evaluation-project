# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("census_income[1].csv")

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 32555             0             0              38   United-States   <=50K
# 32556             0             0              40   United-States    >50K
# 32557             0             0              40   United-States   <=50K
# 32558             0             0              20   United-States   <=50K
# 32559         15024             0              40   United-States    >50K

# %%
df.sample()
# Out:
#        Age          Workclass  Fnlwgt Education  Education_num  \
# 15718   55   Self-emp-not-inc  271795   HS-grad              9
#
#             Marital_status      Occupation Relationship    Race    Sex  \
# 15718   Married-civ-spouse   Other-service      Husband   White   Male
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 15718             0             0              40   United-States   <=50K

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
object_datatype = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        object_datatype.append(x)
print(f"Object Data Type Columns are: ", object_datatype)
# Out:
# Object Data Type Columns are:  ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
integer_datatype = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'int64':
        integer_datatype.append(x)
print(f"float Data Type Columns are: ", integer_datatype)
# Out:
# float Data Type Columns are:  ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # Univariate Analysis

# %%
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
sns.countplot(data=df, x='Workclass')
# Out:
# <Axes: xlabel='Workclass', ylabel='count'>

# %%
df['Marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
sns.countplot(data=df, x='Marital_status')
# Out:
# <Axes: xlabel='Marital_status', ylabel='count'>

# %%
sns.countplot(data=df, x='Education')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(data=df, x='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data=df, x='Relationship')
# Out:
# <Axes: xlabel='Relationship', ylabel='count'>

# %%
sns.countplot(data=df, x='Race')
# Out:
# <Axes: xlabel='Race', ylabel='count'>

# %%
sns.countplot(data=df, x='Sex')
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
print("Rows and Columns before dropping duplicates: ", df.shape)
df.drop_duplicates(inplace=True)
print("Rows and Columns after dropping duplicates: ", df.shape)
# Out:
# Rows and Columns before dropping duplicates:  (32560, 15)
# Rows and Columns after dropping duplicates:  (32536, 15)

# %%
df.nunique().to_frame("Unique Values")
# Out:
#                 Unique Values
# Age                        73
# Workclass                   9
# Fnlwgt                  21647
# Education                  16
# Education_num              16
# Marital_status              7
# Occupation                 15
# Relationship                6
# Race                        5
# Sex                         2
# Capital_gain              119
# Capital_loss               92
# Hours_per_week             94
# Native_country             42
# Income                      2

# %%
df['Workclass'].replace({' ?':' Other-Working-Class'},inplace=True)
df['Occupation'].replace({' ?':' Other-Occupation'},inplace=True)
df['Native_country'].replace({' ?':' Others'},inplace=True)

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x = 'Age', y = 'Income', data=df)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x = 'Hours_per_week', y = 'Income', data=df)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x = 'Fnlwgt', y = 'Income', data=df)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x = 'Education_num', y = 'Income', data=df)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x = 'Capital_gain', y = 'Income', data=df)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.stripplot(x = 'Capital_loss', y = 'Income', data=df)
plt.show()

# %%
tbl = pd.crosstab(df['Race'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Race/Ethenicity details', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Relationship'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Relationship details', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Marital_status'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Marrital status information', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Workclass'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Working Class Names', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Education_num'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Education Number information', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Education'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Education information', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Occupation'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Occupation details', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Native_country'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(17,7))
plt.xlabel('Country Names', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Hours_per_week'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Hours worked per week', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %%
tbl = pd.crosstab(df['Age'], df['Income'])
(tbl.div(tbl.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,5))
plt.xlabel('Age information', fontsize=14)
plt.ylabel('Percentage of People', fontsize=14)
# Out:
# Text(0, 0.5, 'Percentage of People')

# %% [markdown]
# # Multivariate Analysis

# %%
plt.figure(figsize=(7,5))
sns.violinplot(x="Income", y="Age", hue="Sex", data=df)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.violinplot(x="Race", y="Age", hue="Sex", data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x="Relationship", y="Age", hue="Sex", data=df)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x="Marital_status", y="Age", hue="Sex", data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.violinplot(x="Workclass", y="Age", hue="Sex", data=df)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.violinplot(x="Occupation", y="Age", hue="Sex", data=df)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.violinplot(x="Education_num", y="Age", hue="Sex", data=df)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.violinplot(x="Education", y="Age", hue="Sex", data=df)
plt.show()

# %% [markdown]
# # Encoding the categorical object datatype columns

# %%
from scipy.stats import zscore
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# %%
le = LabelEncoder()
df["Income"] = le.fit_transform(df["Income"])
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States       0
# 1             0             0              40   United-States       0
# 2             0             0              40   United-States       0
# 3             0             0              40            Cuba       0
# 4             0             0              40   United-States       0

# %%
oe = OrdinalEncoder()
df['Workclass'] = oe.fit_transform(df['Workclass'].values.reshape(-1,1))
df['Education'] = oe.fit_transform(df['Education'].values.reshape(-1,1))
df['Marital_status'] = oe.fit_transform(df['Marital_status'].values.reshape(-1,1))
df['Occupation'] = oe.fit_transform(df['Occupation'].values.reshape(-1,1))
df['Relationship'] = oe.fit_transform(df['Relationship'].values.reshape(-1,1))
df['Native_country'] = oe.fit_transform(df['Native_country'].values.reshape(-1,1))
df['Race'] = oe.fit_transform(df['Race'].values.reshape(-1,1))
df['Sex'] = oe.fit_transform(df['Sex'].values.reshape(-1,1))
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50        6.0   83311        9.0             13             2.0
# 1   38        4.0  215646       11.0              9             0.0
# 2   53        4.0  234721        1.0              7             2.0
# 3   28        4.0  338409        9.0             13             2.0
# 4   37        4.0  284582       12.0             14             2.0
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0         3.0           0.0   4.0  1.0             0             0
# 1         5.0           1.0   4.0  1.0             0             0
# 2         5.0           0.0   2.0  1.0             0             0
# 3        10.0           5.0   2.0  0.0             0             0
# 4         3.0           5.0   4.0  0.0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13            39.0       0
# 1              40            39.0       0
# 2              40            39.0       0
# 3              40             4.0       0
# 4              40            39.0       0

# %%
print(f"Shape of our data frame post encoding is", df.shape)
df.isnull().sum()
# Out:
# Shape of our data frame post encoding is (32536, 15)
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ce0cd9ee00>,
#   <matplotlib.lines.Line2D at 0x1ce0cd9f0a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ce0cd9f340>,
#   <matplotlib.lines.Line2D at 0x1ce0cd9f5e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ce0cd9eb60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ce0cd9f880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ce0cd9fb20>],
#  'means': []}

# %%
plt.boxplot(df['Fnlwgt'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ce0ce02f50>,
#   <matplotlib.lines.Line2D at 0x1ce0ce030d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ce0ce03370>,
#   <matplotlib.lines.Line2D at 0x1ce0ce03610>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ce0ce02cb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ce0ce038b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ce0ce03b50>],
#  'means': []}

# %%
plt.boxplot(df['Education_num'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ce0640f070>,
#   <matplotlib.lines.Line2D at 0x1ce0640f310>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ce0640f5b0>,
#   <matplotlib.lines.Line2D at 0x1ce0640f850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ce0640edd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ce0640faf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ce0640fd90>],
#  'means': []}

# %%
plt.boxplot(df['Capital_gain'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ce06477400>,
#   <matplotlib.lines.Line2D at 0x1ce064776a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ce064778b0>,
#   <matplotlib.lines.Line2D at 0x1ce06477b50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ce06477160>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ce06477df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ce064b00d0>],
#  'means': []}

# %%
plt.boxplot(df['Capital_loss'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ce062c5c60>,
#   <matplotlib.lines.Line2D at 0x1ce062c5f00>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ce062c61a0>,
#   <matplotlib.lines.Line2D at 0x1ce062c6440>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ce062c59c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ce062c66e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ce062c69b0>],
#  'means': []}

# %%
plt.boxplot(df['Hours_per_week'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ce06348280>,
#   <matplotlib.lines.Line2D at 0x1ce06348520>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ce063487c0>,
#   <matplotlib.lines.Line2D at 0x1ce06348a60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ce06316e00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ce06348d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ce06348fa0>],
#  'means': []}

# %%
num_values = df.drop(['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
                      'Native_country', 'Income'], axis=1)

# %%
plt.style.use('default')
g = sns.pairplot(num_values, diag_kind="kde")
for ax in g.axes.flat:
    ax.tick_params("x", labelrotation=90)
plt.show()

# %%
df.hist(figsize=(15,15))
plt.show()

# %% [markdown]
# # Correlation using a Heatmap

# %%
dfcorr=df.corr()

# %%
dfcorr
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.008658 -0.076448  -0.010551       0.036224
# Workclass       0.008658   1.000000 -0.017959   0.000939      -0.009076
# Fnlwgt         -0.076448  -0.017959  1.000000  -0.028065      -0.043353
# Education      -0.010551   0.000939 -0.028065   1.000000       0.359105
# Education_num   0.036224  -0.009076 -0.043353   0.359105       1.000000
# Marital_status -0.266142  -0.021033  0.028154  -0.038413      -0.069196
# Occupation     -0.006211  -0.000473 -0.000194  -0.034530       0.091507
# Relationship   -0.263744  -0.060656  0.008859  -0.011060      -0.094424
# Race            0.029116   0.053442 -0.021484   0.014307       0.031998
# Sex             0.088708   0.076756  0.027113  -0.027426       0.012181
# Capital_gain    0.077676   0.030576  0.000433   0.030086       0.122661
# Capital_loss    0.057745   0.000970 -0.010267   0.016790       0.079901
# Hours_per_week  0.068515   0.059954 -0.018900   0.055991       0.148426
# Native_country -0.000199  -0.010064 -0.064337   0.077042       0.081568
# Income          0.234039   0.002289 -0.009521   0.079361       0.335299
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# Age                  -0.266142   -0.006211     -0.263744  0.029116  0.088708
# Workclass            -0.021033   -0.000473     -0.060656  0.053442  0.076756
# Fnlwgt                0.028154   -0.000194      0.008859 -0.021484  0.027113
# Education            -0.038413   -0.034530     -0.011060  0.014307 -0.027426
# Education_num        -0.069196    0.091507     -0.094424  0.031998  0.012181
# Marital_status        1.000000    0.028040      0.185542 -0.067942 -0.129425
# Occupation            0.028040    1.000000     -0.039937 -0.004093  0.043583
# Relationship          0.185542   -0.039937      1.000000 -0.116048 -0.582593
# Race                 -0.067942   -0.004093     -0.116048  1.000000  0.087464
# Sex                  -0.129425    0.043583     -0.582593  0.087464  1.000000
# Capital_gain         -0.043373    0.021137     -0.057945  0.011152  0.048486
# Capital_loss         -0.034134    0.011721     -0.061100  0.018916  0.045576
# Hours_per_week       -0.190433    0.004395     -0.248876  0.041921  0.229190
# Native_country       -0.023431   -0.006413     -0.009354  0.131134 -0.002381
# Income               -0.199187    0.045286     -0.250955  0.071855  0.215984
#
#                 Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# Age                 0.077676      0.057745        0.068515       -0.000199
# Workclass           0.030576      0.000970        0.059954       -0.010064
# Fnlwgt              0.000433     -0.010267       -0.018900       -0.064337
# Education           0.030086      0.016790        0.055991        0.077042
# Education_num       0.122661      0.079901        0.148426        0.081568
# Marital_status     -0.043373     -0.034134       -0.190433       -0.023431
# Occupation          0.021137      0.011721        0.004395       -0.006413
# Relationship       -0.057945     -0.061100       -0.248876       -0.009354
# Race                0.011152      0.018916        0.041921        0.131134
# Sex                 0.048486      0.045576        0.229190       -0.002381
# Capital_gain        1.000000     -0.031638        0.078408        0.005346
# Capital_loss       -0.031638      1.000000        0.054229        0.006836
# Hours_per_week      0.078408      0.054229        1.000000        0.003638
# Native_country      0.005346      0.006836        0.003638        1.000000
# Income              0.223340      0.150498        0.229659        0.022165
#
#                   Income
# Age             0.234039
# Workclass       0.002289
# Fnlwgt         -0.009521
# Education       0.079361
# Education_num   0.335299
# Marital_status -0.199187
# Occupation      0.045286
# Relationship   -0.250955
# Race            0.071855
# Sex             0.215984
# Capital_gain    0.223340
# Capital_loss    0.150498
# Hours_per_week  0.229659
# Native_country  0.022165
# Income          1.000000

# %%
sns.heatmap(dfcorr,annot=True, linewidth=1)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
dfcorr['Income'].sort_values(ascending=False).drop('Income').plot.bar()
plt.title("Correlation of Features vs Income Label\n", fontsize=16)
plt.xlabel("\nFeatures List", fontsize=14)
plt.ylabel("Correlation Value", fontsize=12)
plt.show()

# %% [markdown]
# # Using Z Score to remove outliers

# %%
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (32536, 15)
# Shape of the dataframe after removing outliers:  (27763, 15)
# Percentage of data loss post outlier removal:  14.669904106220802

# %%
df.skew()
# Out:
# Age                0.484855
# Workclass         -0.663507
# Fnlwgt             0.629184
# Education         -0.955853
# Education_num     -0.145432
# Marital_status    -0.045123
# Occupation         0.101481
# Relationship       0.753529
# Race              -2.585947
# Sex               -0.689396
# Capital_gain       4.929937
# Capital_loss      29.510814
# Hours_per_week    -0.358912
# Native_country    -4.368853
# Income             1.321803
# dtype: float64

# %% [markdown]
# # Using Log Transform to fix skewness

# %%
for col in integer_datatype:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Age                0.484855
# Workclass         -0.663507
# Fnlwgt            -0.955984
# Education         -0.955853
# Education_num     -0.145432
# Marital_status    -0.045123
# Occupation         0.101481
# Relationship       0.753529
# Race              -2.585947
# Sex               -0.689396
# Capital_gain       3.111123
# Capital_loss      25.003969
# Hours_per_week    -0.358912
# Native_country    -4.368853
# Income             1.321803
# dtype: float64

# %% [markdown]
# # Splitting the dataset into features and Target

# %%
X = df.drop('Income', axis=1)
Y = df['Income']

# %% [markdown]
# # SMOTE

# %%
Y.value_counts()
# Out:
# 0    21535
# 1     6228
# Name: Income, dtype: int64

# %%
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 0    21535
# 1    21535
# Name: Income, dtype: int64

# %% [markdown]
# # Feature Scaling

# %%
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0  0.782922   1.552055 -1.144280  -0.428169       1.015118       -0.319870
# 1 -0.167947   0.052466  0.522712   0.139445      -0.631381       -1.854117
# 2  1.020639   0.052466  0.671277  -2.698625      -1.454630       -0.319870
# 3 -0.247187   0.052466  1.008905   0.423252       1.426742       -0.319870
# 4  0.703682   0.052466  0.001617  -1.279590      -2.277879        0.447253
#
#    Occupation  Relationship      Race       Sex  Capital_gain  Capital_loss  \
# 0   -0.813604     -0.731619  0.308042  0.607157     -0.384992     -0.033144
# 1   -0.355791     -0.109306  0.308042  0.607157     -0.384992     -0.033144
# 2   -0.355791     -0.731619 -3.490382  0.607157     -0.384992     -0.033144
# 3   -0.813604      2.379947  0.308042 -1.693274     -0.384992     -0.033144
# 4    0.330929     -0.109306 -3.490382 -1.693274     -0.384992     -0.033144
#
#    Hours_per_week  Native_country
# 0       -2.657900        0.212219
# 1       -0.151292        0.212219
# 2       -0.151292        0.212219
# 3       -0.151292        0.212219
# 4       -2.379388       -5.835907

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Finding best random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
LR = LogisticRegression()

# %%
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=i)
    lr=LogisticRegression()
    lr.fit(X_train, Y_train)
    pred = lr.predict(X_test)
    acc_score = (accuracy_score(Y_test, pred))*100
    
    if acc_score>maxAccu:
        maxAccu=acc_score
        maxRS=i

print("Best accuracy score is", maxAccu,"on Random State", maxRS)
# Out:
# Best accuracy score is 77.79531946508172 on Random State 725

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
maxAccu=0
maxRS=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.20, random_state=i)
    rfc=RandomForestClassifier()
    rfc.fit(x_train,y_train)
    pred=rfc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9082888321337358  on Random_state  53

# %%
rf=RandomForestClassifier()
rf.fit(X_train, Y_train)
importances = pd.DataFrame({'Features':X.columns, 'Importance':np.round(rf.feature_importances_,3)})
importances
# Out:
#           Features  Importance
# 0              Age       0.143
# 1        Workclass       0.044
# 2           Fnlwgt       0.123
# 3        Education       0.050
# 4    Education_num       0.076
# 5   Marital_status       0.114
# 6       Occupation       0.070
# 7     Relationship       0.188
# 8             Race       0.015
# 9              Sex       0.040
# 10    Capital_gain       0.061
# 11    Capital_loss       0.000
# 12  Hours_per_week       0.068
# 13  Native_country       0.008

# %% [markdown]
# # Machine Learning Model for Classification

# %%
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
def classifier(model, X, Y):
    x_train,x_test,y_train,y_test = train_test_split(X, Y, test_size=0.2, random_state=36)
    
    model.fit(x_train, y_train)

    pred = model.predict(x_test)
    
    acc_score = (accuracy_score(y_test, pred))*100
    print("Accuracy Score:", acc_score)
    
    class_report = classification_report(y_test, pred)
    print("\nClassification Report:\n", class_report)
    
    cv_score = (cross_val_score(model, X, Y, cv=5).mean())*100
    print("Cross Validation Score:", cv_score)
    
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)

# %% [markdown]
# # Logistic Regression

# %%
model = LogisticRegression()
classifier(model, X, Y)
# Out:
# Accuracy Score: 76.79359182725796
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77      4386
#            1       0.76      0.78      0.77      4228
#
#     accuracy                           0.77      8614
#    macro avg       0.77      0.77      0.77      8614
# weighted avg       0.77      0.77      0.77      8614
#
# Cross Validation Score: 76.50336661249129
#
# Accuracy Score - Cross Validation Score is 0.2902252147666644

# %% [markdown]
# # Naive Bayes

# %%
model = GaussianNB()
classifier(model, X, Y)
# Out:
# Accuracy Score: 78.03575574645926
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77      4386
#            1       0.74      0.84      0.79      4228
#
#     accuracy                           0.78      8614
#    macro avg       0.79      0.78      0.78      8614
# weighted avg       0.79      0.78      0.78      8614
#
# Cross Validation Score: 77.20687253308569
#
# Accuracy Score - Cross Validation Score is 0.8288832133735724

# %% [markdown]
# # SVC Classifier

# %%
model = SVC(kernel='rbf')
classifier(model, X, Y)
# Out:
# Accuracy Score: 84.35105641978176
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      4386
#            1       0.80      0.91      0.85      4228
#
#     accuracy                           0.84      8614
#    macro avg       0.85      0.84      0.84      8614
# weighted avg       0.85      0.84      0.84      8614
#
# Cross Validation Score: 84.06315300673322
#
# Accuracy Score - Cross Validation Score is 0.2879034130485394

# %%
model = SVC(kernel='linear')
classifier(model, X, Y)
# Out:
# Accuracy Score: 76.96772695611794
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76      4386
#            1       0.74      0.81      0.78      4228
#
#     accuracy                           0.77      8614
#    macro avg       0.77      0.77      0.77      8614
# weighted avg       0.77      0.77      0.77      8614
#
# Cross Validation Score: 76.85628047364756
#
# Accuracy Score - Cross Validation Score is 0.11144648247038447

# %%
model = SVC(kernel='poly')
classifier(model, X, Y)
# Out:
# Accuracy Score: 81.49524030647783
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      4386
#            1       0.75      0.93      0.83      4228
#
#     accuracy                           0.81      8614
#    macro avg       0.83      0.82      0.81      8614
# weighted avg       0.83      0.81      0.81      8614
#
# Cross Validation Score: 81.01694915254237
#
# Accuracy Score - Cross Validation Score is 0.4782911539354586

# %% [markdown]
# # Decision Tree Classifier

# %%
model = DecisionTreeClassifier()
classifier(model, X, Y)
# Out:
# Accuracy Score: 85.65126538193638
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      4386
#            1       0.85      0.86      0.85      4228
#
#     accuracy                           0.86      8614
#    macro avg       0.86      0.86      0.86      8614
# weighted avg       0.86      0.86      0.86      8614
#
# Cross Validation Score: 85.40747620153239
#
# Accuracy Score - Cross Validation Score is 0.24378918040399356

# %% [markdown]
# # KNeighbors Classifier

# %%
model = KNeighborsClassifier()
classifier(model, X, Y)
# Out:
# Accuracy Score: 85.26816809844439
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.80      0.85      4386
#            1       0.81      0.91      0.86      4228
#
#     accuracy                           0.85      8614
#    macro avg       0.86      0.85      0.85      8614
# weighted avg       0.86      0.85      0.85      8614
#
# Cross Validation Score: 85.14511260738334
#
# Accuracy Score - Cross Validation Score is 0.12305549106105218

# %% [markdown]
# # SGD Classifier

# %%
model = SGDClassifier()
classifier(model, X, Y)
# Out:
# Accuracy Score: 76.59623868121662
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77      4386
#            1       0.76      0.76      0.76      4228
#
#     accuracy                           0.77      8614
#    macro avg       0.77      0.77      0.77      8614
# weighted avg       0.77      0.77      0.77      8614
#
# Cross Validation Score: 76.0924077083817
#
# Accuracy Score - Cross Validation Score is 0.5038309728349191

# %% [markdown]
# # Random Forest Classifier

# %%
model = RandomForestClassifier()
classifier(model, X, Y)
# Out:
# Accuracy Score: 90.37613187833759
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90      4386
#            1       0.89      0.91      0.90      4228
#
#     accuracy                           0.90      8614
#    macro avg       0.90      0.90      0.90      8614
# weighted avg       0.90      0.90      0.90      8614
#
# Cross Validation Score: 89.70513118179706
#
# Accuracy Score - Cross Validation Score is 0.6710006965405313

# %% [markdown]
# # ExtraTrees Classifier

# %%
model = ExtraTreesClassifier()
classifier(model, X, Y)
# Out:
# Accuracy Score: 90.61992105874158
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91      4386
#            1       0.89      0.92      0.91      4228
#
#     accuracy                           0.91      8614
#    macro avg       0.91      0.91      0.91      8614
# weighted avg       0.91      0.91      0.91      8614
#
# Cross Validation Score: 90.29486881820293
#
# Accuracy Score - Cross Validation Score is 0.32505224053865334

# %% [markdown]
# # AdaBoost Classifier

# %%
model = AdaBoostClassifier()
classifier(model, X, Y)
# Out:
# Accuracy Score: 86.48711400046436
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      4386
#            1       0.84      0.89      0.87      4228
#
#     accuracy                           0.86      8614
#    macro avg       0.87      0.87      0.86      8614
# weighted avg       0.87      0.86      0.86      8614
#
# Cross Validation Score: 85.7789644764337
#
# Accuracy Score - Cross Validation Score is 0.7081495240306594

# %% [markdown]
# # Gradient Boosting Classifier

# %%
model = GradientBoostingClassifier()
classifier(model, X, Y)
# Out:
# Accuracy Score: 87.62479684234967
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87      4386
#            1       0.85      0.90      0.88      4228
#
#     accuracy                           0.88      8614
#    macro avg       0.88      0.88      0.88      8614
# weighted avg       0.88      0.88      0.88      8614
#
# Cross Validation Score: 86.80752263756676
#
# Accuracy Score - Cross Validation Score is 0.8172742047829047

# %% [markdown]
# # Hyper Parameter Tuning

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=.20,random_state=36)

# %%
x_test.shape
# Out:
# (8614, 14)

# %%
y_test.shape
# Out:
# (8614,)

# %%
x_train.shape
# Out:
# (34456, 14)

# %%
y_train.shape
# Out:
# (34456,)

# %%
parameters = {'criterion' : ['gini', 'entropy'],
              'max_features' : ['auto', 'sqrt', 'log2'],
              'n_jobs' : [5, 10],
              'random_state' : [None, 36]}

GCV = GridSearchCV(ExtraTreesClassifier(), parameters, cv=5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_features': 'sqrt',
#  'n_jobs': 10,
#  'random_state': None}

# %%
final_modelc = ExtraTreesClassifier(criterion = 'gini', max_features = 'sqrt', n_jobs = 10, random_state = None)

# %%
final_fitc = final_modelc.fit(x_train,y_train)

# %%
final_predc = final_modelc.predict(x_test)

# %%
best_acc_score = (accuracy_score(y_test, final_predc))*100
print("The Accuracy Score for the Best Model is ", best_acc_score)
# Out:
# The Accuracy Score for the Best Model is  90.39934989551892

# %%
final_cv_score = (cross_val_score(final_modelc, X, Y, cv=5).mean())*100
print("Cross Validation Score:", final_cv_score)
# Out:
# Cross Validation Score: 90.37613187833759

# %%
final_class_report = classification_report(y_test, final_predc)
print("\nClassification Report:\n", final_class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90      4386
#            1       0.89      0.92      0.90      4228
#
#     accuracy                           0.90      8614
#    macro avg       0.90      0.90      0.90      8614
# weighted avg       0.90      0.90      0.90      8614

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.metrics import RocCurveDisplay

# %%
mat = confusion_matrix(y_test,final_predc)
plt.subplots(figsize=(12,8))
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# Text(277.72222222222223, 0.5, 'predicted label')

# %% [markdown]
# # AUC ROC curve

# %%
fpr,tpr,thresholds=metrics.roc_curve(y_test,final_predc)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,estimator_name=final_modelc)
display.plot()

# %% [markdown]
# # Saving the model in pickle Format

# %%
import pickle
filename = 'Census_Income_Project_Final_Model.pkl'
pickle.dump(final_modelc, open(filename, 'wb'))
